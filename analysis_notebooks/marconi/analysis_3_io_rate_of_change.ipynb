# %% [markdown]
# ## Import libraries

# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
from datetime import datetime
from IPython.display import Image

import os, sys

project_root = Path.cwd().parent.parent
sys.path.append(str(project_root))
os.chdir(project_root)

sns.set_style("whitegrid")
# %matplotlib inline

# %%
from fmu2ml.analysis.rate_of_change.analyzers import (
    RateOfChangeAnalyzer,
    ImpulseResponseAnalyzer,
    DynamicDataGenerator
)
from fmu2ml.analysis.rate_of_change.visualizers import *

# %%
from raps.config import ConfigManager

SYSTEM_NAME = 'marconi100'
config = ConfigManager(system_name=SYSTEM_NAME).get_config()

# %% [markdown]
# ## Define Parameters

# %%
N_SAMPLES = 2000
OUTPUT_DIR = f'../results/{SYSTEM_NAME}/data_analysis/io_rate_of_change'
os.makedirs(OUTPUT_DIR, exist_ok=True)

N_STEPS = 20
DATA_TYPE = 'combined'  # 'step', 'ramp', 'varying', 'combined'

# Input ranges
INPUT_RANGES = {
    'Q_flow': (config.get('MIN_POWER'), config.get('MAX_POWER')),    # kW
    'T_Air': (288.15, 308.15),   # K
    'T_ext': (283.15, 313.15)    # K
}

# Parallel settings
N_WORKERS = 48
THREADS_PER_WORKER = 1
MEMORY_LIMIT = '64GB'

# Analysis parameters
MAX_LAG = 30
SMOOTH_WINDOW = 5
DT = 1.0  # Time step for derivatives

print(f"System: {SYSTEM_NAME}")
print(f"Data type: {DATA_TYPE}")
print(f"Samples: {N_SAMPLES}")
print(f"Output dir: {OUTPUT_DIR}")

#  Load Configuration
num_cdus = config.get('NUM_CDUS', 49)

# Add analysis-specific settings
config['derivative'] = {'dt': DT, 'smooth_window': SMOOTH_WINDOW}
config['impulse_detection'] = {
    'threshold_percentile': 90,
    'min_change_fraction': 0.1,
    'min_duration': 10
}
config['response_analysis'] = {
    'pre_window': 30,
    'post_window': 60
}

print(f"Number of CDUs: {num_cdus}")
print(f"Configuration loaded")
# Out:
# System: marconi100
# Data type: combined
# Samples: 2000
# Output dir: ../results/marconi100/data_analysis/io_rate_of_change
# Number of CDUs: 49
# Configuration loaded

# %%
# Initialize Components
config_for_components = {k: v for k, v in config.items() if k != 'system_name'}

# Data generator
data_generator = DynamicDataGenerator(
    system_name=SYSTEM_NAME,
    n_workers=N_WORKERS,
    **config_for_components
)

# Analyzers
rate_analyzer = RateOfChangeAnalyzer(
    system_name=SYSTEM_NAME,
    n_workers=N_WORKERS,
    threads_per_worker=THREADS_PER_WORKER,
    memory_limit=MEMORY_LIMIT,
    **config_for_components
)

impulse_analyzer = ImpulseResponseAnalyzer(
    system_name=SYSTEM_NAME,
    n_workers=N_WORKERS,
    threads_per_worker=THREADS_PER_WORKER,
    memory_limit=MEMORY_LIMIT,
    **config_for_components
)

print("Components initialized")
# Out:
# 2026-02-06 09:52:51 - fmu2ml.analysis.rate_of_change.analyzers.dynamic_data_generator - INFO - DynamicDataGenerator initialized for system: marconi100
# 2026-02-06 09:52:51 - fmu2ml.analysis.rate_of_change.analyzers.dynamic_data_generator - INFO - Number of CDUs: 49
# 2026-02-06 09:52:51 - fmu2ml.analysis.rate_of_change.analyzers.dynamic_data_generator - INFO - CDU variation enabled: True
# 2026-02-06 09:52:51 - fmu2ml.analysis.rate_of_change.analyzers.dynamic_data_generator - INFO - Parallel workers (scenario-level): 48
# 2026-02-06 09:52:51 - fmu2ml.analysis.rate_of_change.analyzers.rate_of_change_analyzer - INFO - RateOfChangeAnalyzer initialized for system: marconi100
# 2026-02-06 09:52:51 - fmu2ml.analysis.rate_of_change.analyzers.rate_of_change_analyzer - INFO - Number of CDUs: 49
# 2026-02-06 09:52:51 - fmu2ml.analysis.rate_of_change.analyzers.impulse_response_analyzer - INFO - ImpulseResponseAnalyzer initialized for system: marconi100
# 2026-02-06 09:52:51 - fmu2ml.analysis.rate_of_change.analyzers.impulse_response_analyzer - INFO - Number of CDUs: 49
# Components initialized

# %% [markdown]
# ## Generate Dynamic Data

# %%
# Generate or Load Dynamic Data
data_file = os.path.join(OUTPUT_DIR, 'dynamic_data.parquet')
data = None
if os.path.exists(data_file):
    print(f"Loading {DATA_TYPE} data...")
    data  = pd.read_parquet(data_file)
else: 
    print(f"Generating {DATA_TYPE} data...")
    if DATA_TYPE == 'step':
        data = data_generator.generate_step_response_data(
            n_steps=N_STEPS,
            step_duration=120,
            input_ranges=INPUT_RANGES
        )
    elif DATA_TYPE == 'ramp':
        data = data_generator.generate_ramp_data(
            n_ramps=N_STEPS,
            ramp_duration=60,
            hold_duration=60,
            input_ranges=INPUT_RANGES
        )
    elif DATA_TYPE == 'varying':
        data = data_generator.generate_varying_rate_data(
            n_samples=N_SAMPLES,
            input_ranges=INPUT_RANGES
        )
    else:  # combined
        data = data_generator.generate_combined_dynamic_data(
            n_samples=N_SAMPLES,
            input_ranges=INPUT_RANGES, 
            step_size=1
            
        )
    
    # Save data
    data.to_parquet(data_file)
    print(f"Data saved to: {data_file}")

print(f"Data shape: {data.shape}")
# Out:
# Loading combined data...
# Data shape: (3600, 1230)

# %%
# Prepare Data
prepared_data = rate_analyzer.prepare_data(data)
print(f"Data prepared. Shape: {prepared_data['inputs']['Q_flow'].shape}")
print(f"Input variables: {rate_analyzer.input_vars}")
print(f"Output variables (first 5): {rate_analyzer.output_vars[:5]}")
# Out:
# 2026-02-06 09:57:03 - fmu2ml.analysis.rate_of_change.analyzers.rate_of_change_analyzer - INFO - Preparing data for rate of change analysis...
# 2026-02-06 09:57:03 - fmu2ml.analysis.rate_of_change.analyzers.rate_of_change_analyzer - INFO - Data prepared: 3 inputs, 14 outputs
# Data prepared. Shape: (3600, 49)
# Input variables: ['Q_flow', 'T_Air', 'T_ext']
# Output variables (first 5): ['V_flow_prim_GPM', 'V_flow_sec_GPM', 'W_flow_CDUP_kW', 'T_prim_s_C', 'T_prim_r_C']

# %% [markdown]
# ## Visualize the Data

# %%
from fmu2ml.visualization import StandardInputOutputVisualizer

# %%
viz = StandardInputOutputVisualizer(data)

# %%
viz.plot_inputs(selected_cdus=[1,4,11,28,39],time_range=[0,1200] )

# %%
viz.plot_outputs(selected_cdus=[1,4,11,28,39],time_range=[0,1200] )

# %% [markdown]
# ## 1. Compute Temporal Derivatives

# %%
# Compute Derivatives
print("Computing temporal derivatives...")
derivatives_data = rate_analyzer.compute_derivatives(
    prepared_data,
    dt=DT,
    smooth_window=SMOOTH_WINDOW
)

print(f"Derivatives computed. Shape: {derivatives_data['inputs']['Q_flow'].shape}")
# Out:
# 2026-01-29 20:25:02 - fmu2ml.analysis.rate_of_change.analyzers.rate_of_change_analyzer - INFO - Computing temporal derivatives...
# 2026-01-29 20:25:02 - fmu2ml.analysis.rate_of_change.analyzers.rate_of_change_analyzer - INFO - Computed derivatives for 6 inputs, 28 outputs
# Computing temporal derivatives...
# Derivatives computed. Shape: (3599, 49)

# %%
derivatives_data['inputs'].keys()
# Out:
# dict_keys(['Q_flow', 'Q_flow_level', 'T_Air', 'T_Air_level', 'T_ext', 'T_ext_level'])

# %%
# Visualize Derivatives
# Plot example: Q_flow level and rate
fig, axes = plt.subplots(2, 1, figsize=(14, 6), sharex=True)

sample_range = slice(0, 500)
axes[0].plot(derivatives_data['inputs']['Q_flow'][sample_range], label='Q_flow Level', linewidth=1)
axes[0].set_ylabel('Q_flow (kW)')
axes[0].legend()
axes[0].grid(True, alpha=0.3)

axes[1].plot(derivatives_data['inputs']['Q_flow_level'][sample_range], label='Q_flow Rate', 
             color='orange', linewidth=1)
axes[1].set_ylabel('dQ_flow/dt')
axes[1].set_xlabel('Time Step')
axes[1].legend()
axes[1].grid(True, alpha=0.3)

plt.suptitle('Q_flow: Level vs Rate of Change')
plt.tight_layout()
plt.savefig(os.path.join(OUTPUT_DIR, 'qflow_level_rate_example.png'), dpi=150)
Image(filename=os.path.join(OUTPUT_DIR,'qflow_level_rate_example.png'))

# %% [markdown]
# ## 2. Level vs Rate Effects Comparison

# %%
# Level vs Rate Effect Analysis
print("Analyzing level vs rate effects...")
level_rate_df = rate_analyzer.analyze_all_level_rate_effects(derivatives_data)

print(f"\nRelationships analyzed: {len(level_rate_df)}")

# Effect dominance summary
effect_counts = level_rate_df['dominant_effect'].value_counts()
print("\nEffect Dominance:")
print(effect_counts)

# Display top relationships
print("\nTop 10 Rate-Dominant Effects:")
rate_dominant = level_rate_df[level_rate_df['dominant_effect'] == 'rate'].copy()
rate_dominant = rate_dominant.sort_values('rate_strength', ascending=False)
print(rate_dominant.head(10)[['input', 'output', 'level_strength', 'rate_strength',]])
# Out:
# 2026-01-29 20:25:03 - fmu2ml.analysis.rate_of_change.analyzers.rate_of_change_analyzer - INFO - Analyzing level vs rate effects for all pairs...
# 2026-01-29 20:25:03 - fmu2ml.analysis.rate_of_change.analyzers.rate_of_change_analyzer - INFO - Initializing Dask cluster for rate of change analysis...
# 2026-01-29 20:25:03 - distributed.http.proxy - INFO - To route to workers diagnostics web server please install jupyter-server-proxy: python -m pip install jupyter-server-proxy
# 2026-01-29 20:25:03 - distributed.scheduler - INFO - State start
# 2026-01-29 20:25:03 - distributed.scheduler - INFO -   Scheduler at:     tcp://127.0.0.1:42633
# 2026-01-29 20:25:03 - distributed.scheduler - INFO -   dashboard at:  http://127.0.0.1:36603/status
# 2026-01-29 20:25:03 - distributed.scheduler - INFO - Registering Worker plugin shuffle
# Analyzing level vs rate effects...
# 2026-01-29 20:25:03 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:40575'
# 2026-01-29 20:25:03 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:34835'
# 2026-01-29 20:25:03 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:38887'
# 2026-01-29 20:25:03 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:37855'
# 2026-01-29 20:25:03 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:46201'
# 2026-01-29 20:25:03 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:37223'
# 2026-01-29 20:25:03 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:33249'
# 2026-01-29 20:25:03 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:46631'
# 2026-01-29 20:25:03 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:37505'
# 2026-01-29 20:25:03 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:34137'
# 2026-01-29 20:25:03 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:41267'
# 2026-01-29 20:25:04 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:36237'
# 2026-01-29 20:25:04 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:38677'
# 2026-01-29 20:25:04 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:39435'
# 2026-01-29 20:25:04 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:46563'
# 2026-01-29 20:25:04 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:43983'
# 2026-01-29 20:25:04 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:40453'
# 2026-01-29 20:25:04 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:37159'
# 2026-01-29 20:25:04 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:32809'
# 2026-01-29 20:25:04 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:34285'
# 2026-01-29 20:25:04 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:35641'
# 2026-01-29 20:25:04 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:35039'
# 2026-01-29 20:25:04 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:40863'
# 2026-01-29 20:25:04 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:33331'
# 2026-01-29 20:25:04 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:35471'
# 2026-01-29 20:25:04 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:42757'
# 2026-01-29 20:25:04 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:33865'
# 2026-01-29 20:25:04 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:46755'
# 2026-01-29 20:25:04 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:34949'
# 2026-01-29 20:25:04 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:35577'
# 2026-01-29 20:25:04 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:34245'
# 2026-01-29 20:25:04 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:38573'
# 2026-01-29 20:25:04 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:44417'
# 2026-01-29 20:25:04 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:39131'
# 2026-01-29 20:25:04 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:43613'
# 2026-01-29 20:25:04 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:37055'
# 2026-01-29 20:25:04 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:39261'
# 2026-01-29 20:25:04 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:43321'
# 2026-01-29 20:25:04 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:46783'
# 2026-01-29 20:25:04 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:34625'
# 2026-01-29 20:25:04 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:36333'
# 2026-01-29 20:25:04 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:42363'
# 2026-01-29 20:25:04 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:43771'
# 2026-01-29 20:25:04 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:45225'
# 2026-01-29 20:25:04 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:37273'
# 2026-01-29 20:25:04 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:34983'
# 2026-01-29 20:25:04 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:35071'
# 2026-01-29 20:25:04 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:39005'
# 2026-01-29 20:25:04 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:41617 name: 0
# 2026-01-29 20:25:04 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:41617
# 2026-01-29 20:25:04 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:34706
# 2026-01-29 20:25:04 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:45513 name: 1
# 2026-01-29 20:25:04 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:45513
# 2026-01-29 20:25:04 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:34708
# 2026-01-29 20:25:04 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:39061 name: 2
# 2026-01-29 20:25:04 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:39061
# 2026-01-29 20:25:04 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:34722
# 2026-01-29 20:25:04 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:40033 name: 6
# 2026-01-29 20:25:04 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:40033
# 2026-01-29 20:25:04 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:34732
# 2026-01-29 20:25:04 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:42907 name: 3
# 2026-01-29 20:25:04 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:42907
# 2026-01-29 20:25:04 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:34746
# 2026-01-29 20:25:04 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:39605 name: 4
# 2026-01-29 20:25:04 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:39605
# 2026-01-29 20:25:04 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:34754
# 2026-01-29 20:25:04 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:40185 name: 10
# 2026-01-29 20:25:04 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:40185
# 2026-01-29 20:25:04 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:34768
# 2026-01-29 20:25:04 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:33989 name: 9
# 2026-01-29 20:25:04 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:33989
# 2026-01-29 20:25:04 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:34780
# 2026-01-29 20:25:04 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:35409 name: 7
# 2026-01-29 20:25:04 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:35409
# 2026-01-29 20:25:04 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:34782
# 2026-01-29 20:25:04 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:43753 name: 12
# 2026-01-29 20:25:04 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:43753
# 2026-01-29 20:25:04 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:34800
# 2026-01-29 20:25:04 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:37085 name: 11
# 2026-01-29 20:25:04 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:37085
# 2026-01-29 20:25:04 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:34796
# 2026-01-29 20:25:04 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:33321 name: 8
# 2026-01-29 20:25:04 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:33321
# 2026-01-29 20:25:04 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:34814
# 2026-01-29 20:25:04 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:36743 name: 5
# 2026-01-29 20:25:04 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:36743
# 2026-01-29 20:25:04 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:34822
# 2026-01-29 20:25:04 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:42141 name: 14
# 2026-01-29 20:25:04 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:42141
# 2026-01-29 20:25:04 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:34832
# 2026-01-29 20:25:04 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:40059 name: 18
# 2026-01-29 20:25:04 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:40059
# 2026-01-29 20:25:04 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:34836
# 2026-01-29 20:25:04 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:43787 name: 17
# 2026-01-29 20:25:04 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:43787
# 2026-01-29 20:25:04 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:34864
# 2026-01-29 20:25:04 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:44289 name: 21
# 2026-01-29 20:25:04 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:44289
# 2026-01-29 20:25:04 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:34846
# 2026-01-29 20:25:04 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:37743 name: 25
# 2026-01-29 20:25:04 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:37743
# 2026-01-29 20:25:04 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:34854
# 2026-01-29 20:25:04 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:34521 name: 13
# 2026-01-29 20:25:04 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:34521
# 2026-01-29 20:25:04 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:34880
# 2026-01-29 20:25:04 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:35589 name: 20
# 2026-01-29 20:25:04 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:35589
# 2026-01-29 20:25:04 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:34884
# 2026-01-29 20:25:04 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:43465 name: 15
# 2026-01-29 20:25:04 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:43465
# 2026-01-29 20:25:04 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:34896
# 2026-01-29 20:25:04 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:44907 name: 19
# 2026-01-29 20:25:04 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:44907
# 2026-01-29 20:25:04 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:34906
# 2026-01-29 20:25:04 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:46031 name: 28
# 2026-01-29 20:25:04 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:46031
# 2026-01-29 20:25:04 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:34914
# 2026-01-29 20:25:04 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:38585 name: 23
# 2026-01-29 20:25:04 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:38585
# 2026-01-29 20:25:04 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:34912
# 2026-01-29 20:25:04 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:34313 name: 16
# 2026-01-29 20:25:04 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:34313
# 2026-01-29 20:25:04 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:34922
# 2026-01-29 20:25:04 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:41813 name: 22
# 2026-01-29 20:25:04 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:41813
# 2026-01-29 20:25:04 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:34936
# 2026-01-29 20:25:04 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:41453 name: 24
# 2026-01-29 20:25:04 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:41453
# 2026-01-29 20:25:04 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:34940
# 2026-01-29 20:25:05 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:33585 name: 31
# 2026-01-29 20:25:05 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:33585
# 2026-01-29 20:25:05 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:34960
# 2026-01-29 20:25:05 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:40277 name: 26
# 2026-01-29 20:25:05 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:40277
# 2026-01-29 20:25:05 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:34944
# 2026-01-29 20:25:05 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:38777 name: 32
# 2026-01-29 20:25:05 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:38777
# 2026-01-29 20:25:05 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:34966
# 2026-01-29 20:25:05 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:43561 name: 29
# 2026-01-29 20:25:05 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:43561
# 2026-01-29 20:25:05 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:34974
# 2026-01-29 20:25:05 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:39443 name: 30
# 2026-01-29 20:25:05 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:39443
# 2026-01-29 20:25:05 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:34984
# 2026-01-29 20:25:05 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:45791 name: 27
# 2026-01-29 20:25:05 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:45791
# 2026-01-29 20:25:05 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:34986
# 2026-01-29 20:25:05 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:42973 name: 34
# 2026-01-29 20:25:05 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:42973
# 2026-01-29 20:25:05 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:35000
# 2026-01-29 20:25:05 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:35079 name: 37
# 2026-01-29 20:25:05 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:35079
# 2026-01-29 20:25:05 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:35012
# 2026-01-29 20:25:05 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:46481 name: 33
# 2026-01-29 20:25:05 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:46481
# 2026-01-29 20:25:05 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:35028
# 2026-01-29 20:25:05 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:46833 name: 38
# 2026-01-29 20:25:05 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:46833
# 2026-01-29 20:25:05 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:35034
# 2026-01-29 20:25:05 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:38675 name: 41
# 2026-01-29 20:25:05 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:38675
# 2026-01-29 20:25:05 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:35036
# 2026-01-29 20:25:05 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:42111 name: 40
# 2026-01-29 20:25:05 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:42111
# 2026-01-29 20:25:05 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:35044
# 2026-01-29 20:25:05 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:34079 name: 36
# 2026-01-29 20:25:05 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:34079
# 2026-01-29 20:25:05 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:35054
# 2026-01-29 20:25:05 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:39717 name: 45
# 2026-01-29 20:25:05 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:39717
# 2026-01-29 20:25:05 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:35058
# 2026-01-29 20:25:05 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:44823 name: 35
# 2026-01-29 20:25:05 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:44823
# 2026-01-29 20:25:05 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:35070
# 2026-01-29 20:25:05 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:43727 name: 42
# 2026-01-29 20:25:05 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:43727
# 2026-01-29 20:25:05 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:35094
# 2026-01-29 20:25:05 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:44647 name: 39
# 2026-01-29 20:25:05 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:44647
# 2026-01-29 20:25:05 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:35084
# 2026-01-29 20:25:05 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:39179 name: 47
# 2026-01-29 20:25:05 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:39179
# 2026-01-29 20:25:05 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:35098
# 2026-01-29 20:25:05 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:38029 name: 44
# 2026-01-29 20:25:05 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:38029
# 2026-01-29 20:25:05 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:35108
# 2026-01-29 20:25:05 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:35739 name: 43
# 2026-01-29 20:25:05 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:35739
# 2026-01-29 20:25:05 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:35112
# 2026-01-29 20:25:05 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:36577 name: 46
# 2026-01-29 20:25:05 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:36577
# 2026-01-29 20:25:05 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:35128
# 2026-01-29 20:25:05 - distributed.scheduler - INFO - Receive client connection: Client-81aedb1b-fd7a-11f0-880b-0a580a221eb4
# 2026-01-29 20:25:05 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:35138
# 2026-01-29 20:25:05 - fmu2ml.analysis.rate_of_change.analyzers.rate_of_change_analyzer - INFO - Dask client initialized: http://127.0.0.1:36603/status
# 2026-01-29 20:25:05 - fmu2ml.analysis.rate_of_change.analyzers.rate_of_change_analyzer - INFO - Executing 39 level-rate analysis tasks in parallel...
# 2026-01-29 20:25:14 - fmu2ml.analysis.rate_of_change.analyzers.rate_of_change_analyzer - INFO - Computed level-rate metrics for 39 pairs
# Relationships analyzed: 39
#
# Effect Dominance:
# dominant_effect
# level    27
# rate      8
# mixed     4
# Name: count, dtype: int64
#
# Top 10 Rate-Dominant Effects:
#     input           output  level_strength  rate_strength
# 26  T_ext  V_flow_prim_GPM        0.038273       0.056263
# 36  T_ext     p_sec_r_psig        0.022201       0.034846
# 35  T_ext     p_sec_s_psig        0.022206       0.034846
# 15  T_Air   W_flow_CDUP_kW        0.012588       0.034201
# 18  T_Air        T_sec_s_C        0.015053       0.034101
# 32  T_ext        T_sec_r_C        0.019472       0.033670
# 31  T_ext        T_sec_s_C        0.018079       0.033332
# 28  T_ext   W_flow_CDUP_kW        0.018701       0.033113
# 2026-01-29 20:25:52 - distributed.scheduler - INFO - Remove client Client-81aedb1b-fd7a-11f0-880b-0a580a221eb4
# 2026-01-29 20:25:52 - distributed.core - INFO - Received 'close-stream' from tcp://127.0.0.1:35138; closing.
# 2026-01-29 20:25:52 - distributed.scheduler - INFO - Remove client Client-81aedb1b-fd7a-11f0-880b-0a580a221eb4
# 2026-01-29 20:25:52 - distributed.scheduler - INFO - Close client connection: Client-81aedb1b-fd7a-11f0-880b-0a580a221eb4

# %%
# Level vs Rate - Detailed Analysis
# Analyze by input
for input_var in ['Q_flow', 'T_Air', 'T_ext']:
    input_data = level_rate_df[level_rate_df['input'] == input_var]
    
    print(f"\n{input_var} Analysis:")
    print(f"  Total relationships: {len(input_data)}")
    print(f"  Level-dominant: {(input_data['dominant_effect'] == 'level').sum()}")
    print(f"  Rate-dominant: {(input_data['dominant_effect'] == 'rate').sum()}")
    print(f"  Mixed: {(input_data['dominant_effect'] == 'mixed').sum()}")
    print(f"  Avg level strength: {input_data['level_strength'].mean():.3f}")
    print(f"  Avg rate strength: {input_data['rate_strength'].mean():.3f}")
# Out:
# Q_flow Analysis:
#   Total relationships: 13
#   Level-dominant: 12
#   Rate-dominant: 0
#   Mixed: 1
#   Avg level strength: 0.291
#   Avg rate strength: 0.043
#
# T_Air Analysis:
#   Total relationships: 13
#   Level-dominant: 9
#   Rate-dominant: 2
#   Mixed: 2
#   Avg level strength: 0.194
#   Avg rate strength: 0.047
#
# T_ext Analysis:
#   Total relationships: 13
#   Level-dominant: 6
#   Rate-dominant: 6
#   Mixed: 1
#   Avg level strength: 0.111
#   Avg rate strength: 0.051

# %% [markdown]
# ## 3. Response Lag Analysis

# %%
# Response Lag Analysis
print("Analyzing response lags...")
lag_df = rate_analyzer.analyze_response_lags(
    prepared_data,
    max_lag=MAX_LAG
)

print(f"\nRelationships analyzed: {len(lag_df)}")
print(f"Average optimal lag: {lag_df['optimal_lag'].mean():.1f} steps")
print(f"Average max correlation: {lag_df['max_correlation'].mean():.3f}")

# Display relationships with significant lags
significant_lags = lag_df[lag_df['optimal_lag'] > 5]
print(f"\nRelationships with lag > 5 steps: {len(significant_lags)}")
print(significant_lags.nlargest(10, 'optimal_lag')[['input', 'output', 'optimal_lag', 'max_correlation']])
# Out:
# 2026-01-29 20:25:14 - fmu2ml.analysis.rate_of_change.analyzers.rate_of_change_analyzer - INFO - Analyzing response lags (max_lag=30)...
# 2026-01-29 20:25:14 - fmu2ml.analysis.rate_of_change.analyzers.rate_of_change_analyzer - INFO - Executing 39 lag analysis tasks...
# Analyzing response lags...
# 2026-01-29 20:25:20 - fmu2ml.analysis.rate_of_change.analyzers.rate_of_change_analyzer - INFO - Computed lag analysis for 39 pairs
# Relationships analyzed: 39
# Average optimal lag: 6.7 steps
# Average max correlation: 0.041
#
# Relationships with lag > 5 steps: 23
#      input           output  optimal_lag  max_correlation
# 0   Q_flow  V_flow_prim_GPM           30         0.430715
# 2   Q_flow   W_flow_CDUP_kW           30        -0.443879
# 3   Q_flow       T_prim_s_C           30         0.084072
# 4   Q_flow       T_prim_r_C           30        -0.347509
# 5   Q_flow        T_sec_s_C           30        -0.440811
# 6   Q_flow        T_sec_r_C           30        -0.422000
# 7   Q_flow    p_prim_s_psig           30        -0.280169
# 8   Q_flow    p_prim_r_psig           30        -0.329402
# 13   T_Air  V_flow_prim_GPM           30        -0.312200
# 15   T_Air   W_flow_CDUP_kW           30         0.219935

# %%
# Response Lag - By Input
for input_var in ['Q_flow', 'T_Air', 'T_ext']:
    input_lags = lag_df[lag_df['input'] == input_var]
    
    print(f"\n{input_var} Lag Analysis:")
    print(f"  Avg optimal lag: {input_lags['optimal_lag'].mean():.1f} steps")
    print(f"  Avg max correlation: {input_lags['max_correlation'].mean():.3f}")
    print(f"  Max lag observed: {input_lags['optimal_lag'].max():.0f} steps")
# Out:
# Q_flow Lag Analysis:
#   Avg optimal lag: 11.5 steps
#   Avg max correlation: 0.083
#   Max lag observed: 30 steps
#
# T_Air Lag Analysis:
#   Avg optimal lag: 19.7 steps
#   Avg max correlation: 0.012
#   Max lag observed: 30 steps
#
# T_ext Lag Analysis:
#   Avg optimal lag: -11.0 steps
#   Avg max correlation: 0.028
#   Max lag observed: 30 steps

# %% [markdown]
# ## 4. Impulse Response Analysis

# %%
# Detect Step Changes for Impulse Analysis
print("Detecting step changes...")
impulse_prepared = impulse_analyzer.prepare_data(data)

step_events = impulse_analyzer.detect_step_changes(
    impulse_prepared,
    threshold_percentile=config['impulse_detection']['threshold_percentile'],
    min_change_fraction=config['impulse_detection']['min_change_fraction'],
    min_duration=config['impulse_detection']['min_duration']
)

print(f"\nStep changes detected:")
for input_var, events in step_events.items():
    print(f"  {input_var}: {len(events)} events")
# Out:
# 2026-01-29 20:25:20 - fmu2ml.analysis.rate_of_change.analyzers.impulse_response_analyzer - INFO - Preparing data for impulse response analysis...
# 2026-01-29 20:25:20 - fmu2ml.analysis.rate_of_change.analyzers.impulse_response_analyzer - INFO - Prepared 3 inputs, 12 outputs
# 2026-01-29 20:25:20 - fmu2ml.analysis.rate_of_change.analyzers.impulse_response_analyzer - INFO - Detecting step changes in inputs...
# 2026-01-29 20:25:20 - fmu2ml.analysis.rate_of_change.analyzers.impulse_response_analyzer - WARNING - No step changes detected in Q_flow
# 2026-01-29 20:25:20 - fmu2ml.analysis.rate_of_change.analyzers.impulse_response_analyzer - WARNING - No step changes detected in T_Air
# 2026-01-29 20:25:20 - fmu2ml.analysis.rate_of_change.analyzers.impulse_response_analyzer - INFO -   T_ext: 8 step changes detected
# Detecting step changes...
#
# Step changes detected:
#   Q_flow: 0 events
#   T_Air: 0 events
#   T_ext: 8 events

# %%
#  Impulse Response Analysis
print("Analyzing impulse responses...")
response_df = impulse_analyzer.analyze_all_responses(
    impulse_prepared,
    step_events,
    pre_window=config['response_analysis']['pre_window'],
    post_window=config['response_analysis']['post_window']
)

print(f"\nResponses analyzed: {len(response_df)}")
print(f"\nResponse characteristics:")
print(f"  Avg rise time: {response_df['rise_time'].mean():.1f} steps")
print(f"  Avg settling time: {response_df['settling_time'].mean():.1f} steps")
print(f"  Avg gain: {response_df['gain'].mean():.4f}")
print(f"  Avg time constant: {response_df['time_constant'].mean():.1f} steps")
# Out:
# 2026-01-29 20:25:20 - fmu2ml.analysis.rate_of_change.analyzers.impulse_response_analyzer - INFO - Analyzing impulse responses for all input-output pairs...
# 2026-01-29 20:25:20 - fmu2ml.analysis.rate_of_change.analyzers.impulse_response_analyzer - INFO - Initializing Dask cluster for impulse response analysis...
# 2026-01-29 20:25:20 - distributed.scheduler - INFO - State start
# 2026-01-29 20:25:21 - distributed.scheduler - INFO -   Scheduler at:     tcp://127.0.0.1:34963
# 2026-01-29 20:25:21 - distributed.scheduler - INFO -   dashboard at:  http://127.0.0.1:37237/status
# 2026-01-29 20:25:21 - distributed.scheduler - INFO - Registering Worker plugin shuffle
# Analyzing impulse responses...
# 2026-01-29 20:25:21 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:46571'
# 2026-01-29 20:25:21 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:34889'
# 2026-01-29 20:25:21 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:38343'
# 2026-01-29 20:25:21 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:44103'
# 2026-01-29 20:25:21 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:42319'
# 2026-01-29 20:25:21 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:36035'
# 2026-01-29 20:25:21 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:42965'
# 2026-01-29 20:25:21 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:45929'
# 2026-01-29 20:25:21 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:40101'
# 2026-01-29 20:25:21 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:38161'
# 2026-01-29 20:25:21 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:44157'
# 2026-01-29 20:25:21 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:39877'
# 2026-01-29 20:25:21 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:46009'
# 2026-01-29 20:25:21 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:33317'
# 2026-01-29 20:25:21 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:38031'
# 2026-01-29 20:25:21 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:35651'
# 2026-01-29 20:25:21 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:33453'
# 2026-01-29 20:25:21 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:39013'
# 2026-01-29 20:25:21 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:38543'
# 2026-01-29 20:25:21 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:35617'
# 2026-01-29 20:25:21 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:37403'
# 2026-01-29 20:25:21 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:41205'
# 2026-01-29 20:25:21 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:38355'
# 2026-01-29 20:25:21 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:40219'
# 2026-01-29 20:25:21 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:41773'
# 2026-01-29 20:25:21 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:44911'
# 2026-01-29 20:25:21 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:44313'
# 2026-01-29 20:25:21 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:46593'
# 2026-01-29 20:25:21 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:44343'
# 2026-01-29 20:25:21 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:43467'
# 2026-01-29 20:25:21 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:45835'
# 2026-01-29 20:25:21 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:41069'
# 2026-01-29 20:25:21 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:44793'
# 2026-01-29 20:25:21 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:40617'
# 2026-01-29 20:25:21 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:41195'
# 2026-01-29 20:25:22 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:34539'
# 2026-01-29 20:25:22 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:33213'
# 2026-01-29 20:25:22 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:35591'
# 2026-01-29 20:25:22 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:42789'
# 2026-01-29 20:25:22 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:34247'
# 2026-01-29 20:25:22 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:36787'
# 2026-01-29 20:25:22 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:35971'
# 2026-01-29 20:25:22 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:41649'
# 2026-01-29 20:25:22 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:33503'
# 2026-01-29 20:25:22 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:33413'
# 2026-01-29 20:25:22 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:46651'
# 2026-01-29 20:25:22 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:38737'
# 2026-01-29 20:25:22 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:35149'
# 2026-01-29 20:25:22 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:45883 name: 1
# 2026-01-29 20:25:22 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:45883
# 2026-01-29 20:25:22 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:56202
# 2026-01-29 20:25:22 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:41147 name: 0
# 2026-01-29 20:25:22 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:41147
# 2026-01-29 20:25:22 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:56214
# 2026-01-29 20:25:22 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:44695 name: 2
# 2026-01-29 20:25:22 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:44695
# 2026-01-29 20:25:22 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:56222
# 2026-01-29 20:25:22 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:32979 name: 3
# 2026-01-29 20:25:22 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:32979
# 2026-01-29 20:25:22 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:56234
# 2026-01-29 20:25:22 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:43055 name: 6
# 2026-01-29 20:25:22 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:43055
# 2026-01-29 20:25:22 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:56244
# 2026-01-29 20:25:22 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:44561 name: 5
# 2026-01-29 20:25:22 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:44561
# 2026-01-29 20:25:22 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:56258
# 2026-01-29 20:25:22 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:38491 name: 4
# 2026-01-29 20:25:22 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:38491
# 2026-01-29 20:25:22 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:56268
# 2026-01-29 20:25:22 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:38787 name: 7
# 2026-01-29 20:25:22 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:38787
# 2026-01-29 20:25:22 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:56274
# 2026-01-29 20:25:22 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:44387 name: 9
# 2026-01-29 20:25:22 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:44387
# 2026-01-29 20:25:22 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:56276
# 2026-01-29 20:25:22 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:43337 name: 11
# 2026-01-29 20:25:22 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:43337
# 2026-01-29 20:25:22 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:56282
# 2026-01-29 20:25:22 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:38395 name: 8
# 2026-01-29 20:25:22 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:38395
# 2026-01-29 20:25:22 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:56284
# 2026-01-29 20:25:22 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:40621 name: 17
# 2026-01-29 20:25:22 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:40621
# 2026-01-29 20:25:22 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:56288
# 2026-01-29 20:25:22 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:44139 name: 10
# 2026-01-29 20:25:22 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:44139
# 2026-01-29 20:25:22 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:56306
# 2026-01-29 20:25:22 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:46667 name: 16
# 2026-01-29 20:25:22 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:46667
# 2026-01-29 20:25:22 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:56302
# 2026-01-29 20:25:22 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:38971 name: 13
# 2026-01-29 20:25:22 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:38971
# 2026-01-29 20:25:22 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:56310
# 2026-01-29 20:25:22 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:36695 name: 14
# 2026-01-29 20:25:22 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:36695
# 2026-01-29 20:25:22 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:56320
# 2026-01-29 20:25:22 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:39807 name: 20
# 2026-01-29 20:25:22 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:39807
# 2026-01-29 20:25:22 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:56326
# 2026-01-29 20:25:22 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:35351 name: 18
# 2026-01-29 20:25:22 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:35351
# 2026-01-29 20:25:22 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:56340
# 2026-01-29 20:25:22 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:36315 name: 19
# 2026-01-29 20:25:22 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:36315
# 2026-01-29 20:25:22 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:56356
# 2026-01-29 20:25:22 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:43405 name: 15
# 2026-01-29 20:25:22 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:43405
# 2026-01-29 20:25:22 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:56366
# 2026-01-29 20:25:22 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:36311 name: 21
# 2026-01-29 20:25:22 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:36311
# 2026-01-29 20:25:22 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:56376
# 2026-01-29 20:25:22 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:35643 name: 12
# 2026-01-29 20:25:22 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:35643
# 2026-01-29 20:25:22 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:56392
# 2026-01-29 20:25:22 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:41013 name: 26
# 2026-01-29 20:25:22 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:41013
# 2026-01-29 20:25:22 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:56406
# 2026-01-29 20:25:22 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:33489 name: 24
# 2026-01-29 20:25:22 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:33489
# 2026-01-29 20:25:22 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:56408
# 2026-01-29 20:25:22 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:39767 name: 22
# 2026-01-29 20:25:22 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:39767
# 2026-01-29 20:25:22 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:56410
# 2026-01-29 20:25:22 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:41647 name: 23
# 2026-01-29 20:25:22 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:41647
# 2026-01-29 20:25:22 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:56424
# 2026-01-29 20:25:22 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:44185 name: 25
# 2026-01-29 20:25:22 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:44185
# 2026-01-29 20:25:22 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:56434
# 2026-01-29 20:25:22 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:43831 name: 28
# 2026-01-29 20:25:22 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:43831
# 2026-01-29 20:25:22 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:56448
# 2026-01-29 20:25:22 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:38663 name: 27
# 2026-01-29 20:25:22 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:38663
# 2026-01-29 20:25:22 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:56460
# 2026-01-29 20:25:22 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:44255 name: 32
# 2026-01-29 20:25:22 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:44255
# 2026-01-29 20:25:22 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:56462
# 2026-01-29 20:25:22 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:33515 name: 30
# 2026-01-29 20:25:22 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:33515
# 2026-01-29 20:25:22 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:56468
# 2026-01-29 20:25:22 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:39233 name: 29
# 2026-01-29 20:25:22 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:39233
# 2026-01-29 20:25:22 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:56480
# 2026-01-29 20:25:22 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:36003 name: 33
# 2026-01-29 20:25:22 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:36003
# 2026-01-29 20:25:22 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:56486
# 2026-01-29 20:25:22 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:43833 name: 31
# 2026-01-29 20:25:22 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:43833
# 2026-01-29 20:25:22 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:56504
# 2026-01-29 20:25:22 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:45361 name: 37
# 2026-01-29 20:25:22 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:45361
# 2026-01-29 20:25:22 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:56492
# 2026-01-29 20:25:22 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:39363 name: 34
# 2026-01-29 20:25:22 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:39363
# 2026-01-29 20:25:22 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:56514
# 2026-01-29 20:25:22 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:35905 name: 35
# 2026-01-29 20:25:22 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:35905
# 2026-01-29 20:25:22 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:56528
# 2026-01-29 20:25:22 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:44651 name: 36
# 2026-01-29 20:25:22 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:44651
# 2026-01-29 20:25:22 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:56542
# 2026-01-29 20:25:22 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:33253 name: 40
# 2026-01-29 20:25:22 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:33253
# 2026-01-29 20:25:22 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:56552
# 2026-01-29 20:25:22 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:36903 name: 39
# 2026-01-29 20:25:22 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:36903
# 2026-01-29 20:25:22 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:56548
# 2026-01-29 20:25:22 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:34643 name: 38
# 2026-01-29 20:25:22 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:34643
# 2026-01-29 20:25:22 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:56566
# 2026-01-29 20:25:22 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:43155 name: 42
# 2026-01-29 20:25:22 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:43155
# 2026-01-29 20:25:22 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:56580
# 2026-01-29 20:25:22 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:36441 name: 41
# 2026-01-29 20:25:22 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:36441
# 2026-01-29 20:25:22 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:56592
# 2026-01-29 20:25:22 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:37593 name: 43
# 2026-01-29 20:25:22 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:37593
# 2026-01-29 20:25:22 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:56608
# 2026-01-29 20:25:22 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:46765 name: 46
# 2026-01-29 20:25:22 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:46765
# 2026-01-29 20:25:22 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:56624
# 2026-01-29 20:25:23 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:45415 name: 47
# 2026-01-29 20:25:23 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:45415
# 2026-01-29 20:25:23 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:56632
# 2026-01-29 20:25:23 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:37455 name: 45
# 2026-01-29 20:25:23 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:37455
# 2026-01-29 20:25:23 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:56640
# 2026-01-29 20:25:23 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:40371 name: 44
# 2026-01-29 20:25:23 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:40371
# 2026-01-29 20:25:23 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:56642
# 2026-01-29 20:25:23 - distributed.scheduler - INFO - Receive client connection: Client-8c54c71a-fd7a-11f0-880b-0a580a221eb4
# 2026-01-29 20:25:23 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:56650
# 2026-01-29 20:25:23 - fmu2ml.analysis.rate_of_change.analyzers.impulse_response_analyzer - INFO - Dask client initialized: http://127.0.0.1:37237/status
# 2026-01-29 20:25:23 - fmu2ml.analysis.rate_of_change.analyzers.impulse_response_analyzer - INFO - Executing 96 response analysis tasks...
# 2026-01-29 20:25:33 - fmu2ml.analysis.rate_of_change.analyzers.impulse_response_analyzer - INFO - Analyzed 96 response events
# Responses analyzed: 96
#
# Response characteristics:
#   Avg rise time: 32.1 steps
#   Avg settling time: 56.0 steps
#   Avg gain: -0.0197
#   Avg time constant: 24.5 steps
# 2026-01-29 20:25:52 - distributed.scheduler - INFO - Remove client Client-8c54c71a-fd7a-11f0-880b-0a580a221eb4
# 2026-01-29 20:25:52 - distributed.core - INFO - Received 'close-stream' from tcp://127.0.0.1:56650; closing.
# 2026-01-29 20:25:52 - distributed.scheduler - INFO - Remove client Client-8c54c71a-fd7a-11f0-880b-0a580a221eb4
# 2026-01-29 20:25:52 - distributed.scheduler - INFO - Close client connection: Client-8c54c71a-fd7a-11f0-880b-0a580a221eb4

# %%
response_df.columns
# Out:
# Index(['input', 'output', 'step_index', 'step_magnitude', 'step_direction',
#        'initial_value', 'final_value', 'output_change', 'gain', 'rise_time',
#        'rise_time_90', 'settling_time', 'overshoot_pct', 'time_constant',
#        'fit_r2', 'response_order'],
#       dtype='object')

# %%
# Impulse Response - Detailed Results
# Display sample responses
print("Sample Impulse Responses:")
print(response_df.head(10)[['input', 'output', 'step_index','step_magnitude', 'step_direction',
       'initial_value', 'final_value', 'output_change', 'gain', 'rise_time',
       'rise_time_90', 'settling_time', 'overshoot_pct', 'time_constant',
       'fit_r2', 'response_order']])

# Analyze by input
for input_var in step_events.keys():
    input_responses = response_df[response_df['input'] == input_var]
    
    if not input_responses.empty:
        print(f"\n{input_var} Response Characteristics:")
        print(f"  Avg rise time: {input_responses['rise_time'].mean():.1f} steps")
        print(f"  Avg settling time: {input_responses['settling_time'].mean():.1f} steps")
        print(f"  Avg gain: {input_responses['gain'].mean():.4f}")
        print(f"  Avg overshoot: {input_responses['overshoot_pct'].mean():.1f}%")
# Out:
# Sample Impulse Responses:
#    input           output  step_index  step_magnitude step_direction  \
# 0  T_ext  V_flow_prim_GPM         111        27.00000             up
# 1  T_ext  V_flow_prim_GPM         223       -27.00000           down
# 2  T_ext  V_flow_prim_GPM         335        27.00000             up
# 3  T_ext  V_flow_prim_GPM         447       -27.00000           down
# 4  T_ext  V_flow_prim_GPM         559        27.00000             up
# 5  T_ext  V_flow_prim_GPM         671       -27.00000           down
# 6  T_ext  V_flow_prim_GPM         783        27.00000             up
# 7  T_ext  V_flow_prim_GPM         897       -23.71875           down
# 8  T_ext   V_flow_sec_GPM         111        27.00000             up
# 9  T_ext   V_flow_sec_GPM         223       -27.00000           down
#
#    initial_value  final_value  output_change      gain  rise_time  \
# 0       8.779860     8.782715       0.002855  0.000106         35
# 1       8.782211     8.776769      -0.005442  0.000202         41
# 2       8.774407     8.776685       0.002279  0.000084         30
# 3       8.775674     8.769314      -0.006359  0.000236         42
# 4       8.765929     8.767161       0.001232  0.000046         23
# 5       8.765290     8.758239      -0.007051  0.000261         42
# 6       8.754411     8.755366       0.000954  0.000035         20
# 7       8.753264     8.746481      -0.006783  0.000286         42
# 8     317.459492   317.461023       0.001531  0.000057          0
# 9     317.460895   317.461191       0.000296 -0.000011          3
#
#    rise_time_90  settling_time  overshoot_pct  time_constant    fit_r2  \
# 0            48             51       4.691717      16.210526  0.362573
# 1            49             60      -6.640948      18.868021  0.567144
# 2            48             51       4.552058      12.380301 -0.081979
# 3            49             60      -6.966741      19.197086  0.588345
# 4            47             50       2.151178       8.569362 -0.668575
# 5            49             60      -6.906775      19.171457  0.609068
# 6            47             50       1.572619       7.296493 -0.920577
# 7            48             60      -6.348837      18.638191  0.617274
# 8             1             60      46.509898      73.293007 -0.149382
# 9             3             60     610.115463            NaN       NaN
#
#   response_order
# 0   higher_order
# 1   higher_order
# 2   higher_order
# 3   higher_order
# 4   higher_order
# 5   higher_order
# 6   higher_order
# 7   higher_order
# 8   higher_order
# 9        unknown
#
# T_ext Response Characteristics:
#   Avg rise time: 32.1 steps
#   Avg settling time: 56.0 steps
#   Avg gain: -0.0197
#   Avg overshoot: 20.6%

# %%
# Response Summary Statistics
response_summary_df = impulse_analyzer.summarize_response_characteristics(response_df)

print("Response Summary by Input-Output Pair:")
print(response_summary_df.head(10)[['input', 'output', 'n_events', 
                                     'rise_time_mean', 'gain_mean', 
                                     'time_constant_mean']])

#  Combined Dynamic Effects Summary
if not level_rate_df.empty and not lag_df.empty:
    print("Creating combined dynamics summary...")
    dynamics_summary = rate_analyzer.summarize_dynamic_effects(level_rate_df, lag_df)
    
    print(f"\nDynamics summary: {len(dynamics_summary)} relationships")
    print("\nSample entries:")
    print(dynamics_summary.head(10)[['input', 'output', 'dominant_effect', 
                                     'level_strength', 'rate_strength', 
                                     'optimal_lag']])
# Out:
# 2026-01-29 20:25:33 - fmu2ml.analysis.rate_of_change.analyzers.impulse_response_analyzer - INFO - Creating response characteristics summary...
# 2026-01-29 20:25:33 - fmu2ml.analysis.rate_of_change.analyzers.rate_of_change_analyzer - INFO - Creating dynamic effects summary...
# Response Summary by Input-Output Pair:
#    input              output  n_events  rise_time_mean  gain_mean  \
# 0  T_ext          T_prim_r_C         8          45.375  -0.001905
# 1  T_ext          T_prim_s_C         8          39.500  -0.060193
# 2  T_ext           T_sec_r_C         8          40.250  -0.000187
# 3  T_ext           T_sec_s_C         8          44.875  -0.001103
# 4  T_ext     V_flow_prim_GPM         8          34.375   0.000157
# 5  T_ext  V_flow_prim_GPM_dc         8          28.375  -0.184053
# 6  T_ext      V_flow_sec_GPM         8           0.875  -0.000020
# 7  T_ext      W_flow_CDUP_kW         8          45.125  -0.000005
# 8  T_ext       p_prim_r_psig         8          30.875   0.005382
# 9  T_ext       p_prim_s_psig         8          33.125   0.005835
#
#    time_constant_mean
# 0           19.522676
# 1           16.703743
# 2           19.794230
# 3           19.192816
# 4           15.041430
# 5           13.501665
# 6           97.149138
# 7           20.173218
# 8           12.866672
# 9           13.002990
# Creating combined dynamics summary...
#
# Dynamics summary: 39 relationships
#
# Sample entries:
#     input           output dominant_effect  level_strength  rate_strength  \
# 0  Q_flow  V_flow_prim_GPM           level        0.200761       0.014688
# 1  Q_flow   V_flow_sec_GPM           level        0.739285       0.420045
# 2  Q_flow   W_flow_CDUP_kW           level        0.127284       0.025710
# 3  Q_flow       T_prim_s_C           level        0.041176       0.008360
# 4  Q_flow       T_prim_r_C           level        0.138515       0.013337
# 5  Q_flow        T_sec_s_C           level        0.123460       0.024053
# 6  Q_flow        T_sec_r_C           level        0.092443       0.028002
# 7  Q_flow    p_prim_s_psig           level        0.132557       0.010696
# 8  Q_flow    p_prim_r_psig           level        0.155042       0.011906
# 9  Q_flow     p_sec_s_psig           level        0.926461       0.001406
#
#    optimal_lag
# 0           30
# 1           26
# 2           30
# 3           30
# 4           30
# 5           30
# 6           30
# 7           30
# 8           30
# 9          -28

# %% [markdown]
# ## Visualizations

# %%
# Visualizations - Level vs Rate Comparisons
viz_dir = os.path.join(OUTPUT_DIR, 'visualizations')
os.makedirs(viz_dir, exist_ok=True)

print("Creating level vs rate comparison plots...")
create_rate_comparison_plots(
    derivatives_data,
    level_rate_df,
    viz_dir,
    n_workers=N_WORKERS
)

from IPython.display import Image

# Display example plot
example_plots = [f for f in os.listdir(viz_dir) if f.startswith('rate_comparison_')]
if example_plots:
    Image(filename=os.path.join(viz_dir, example_plots[0]))
# Out:
# 2026-01-29 20:25:33 - fmu2ml.analysis.rate_of_change.visualizers.rate_comparison_visualizer - INFO - Creating rate comparison plots in parallel...
# Creating level vs rate comparison plots...
# 2026-01-29 20:25:36 - fmu2ml.analysis.rate_of_change.visualizers.rate_comparison_visualizer - INFO - Created 39/39 rate comparison plots

# %%
Image(filename=os.path.join(viz_dir, 'rate_comparison_Q_flow_V_flow_prim_GPM.png'))

# %%
# Visualizations - Correlation Bars
create_level_rate_correlation_bars(level_rate_df, viz_dir)
Image(filename=os.path.join(viz_dir, 'level_rate_overall_summary.png'))
# Out:
# 2026-01-29 20:25:36 - fmu2ml.analysis.rate_of_change.visualizers.level_rate_bar_visualizer - INFO - Creating level vs rate correlation bar charts...
# 2026-01-29 20:25:36 - matplotlib.text - WARNING - posx and posy should be finite values
# 2026-01-29 20:25:37 - matplotlib.text - WARNING - posx and posy should be finite values
# 2026-01-29 20:25:37 - matplotlib.text - WARNING - posx and posy should be finite values
# 2026-01-29 20:25:38 - matplotlib.text - WARNING - posx and posy should be finite values
# 2026-01-29 20:25:38 - matplotlib.text - WARNING - posx and posy should be finite values
# 2026-01-29 20:25:39 - matplotlib.text - WARNING - posx and posy should be finite values
# 2026-01-29 20:25:39 - matplotlib.text - WARNING - posx and posy should be finite values
# 2026-01-29 20:25:40 - matplotlib.text - WARNING - posx and posy should be finite values
# 2026-01-29 20:25:40 - matplotlib.text - WARNING - posx and posy should be finite values
# 2026-01-29 20:25:43 - fmu2ml.analysis.rate_of_change.visualizers.level_rate_bar_visualizer - INFO - Created level vs rate correlation bar charts

# %%
# Visualizations - Time Series Overlays
if not step_events:
    print("Creating time series overlay plots...")
    create_time_series_overlay_plots(
        prepared_data,
        derivatives_data,
        step_events,
        viz_dir
    )
    
    # Display example
    overlay_plots = [f for f in os.listdir(viz_dir) if f.startswith('time_series_')]
    
Image(filename=os.path.join(viz_dir, 'time_series_overlay_Q_flow.png'))

# %%
# Visualizations - Impulse Responses
if not response_df.empty:
    response_curves = impulse_analyzer.get_response_curves()
    
    print("Creating impulse response plots...")
    create_impulse_response_plots(
        response_curves,
        response_df,
        viz_dir,
        n_workers=N_WORKERS,
        max_plots=50
    )
    
    # Display example
    impulse_plots = [f for f in os.listdir(viz_dir) if f.startswith('impulse_response_')]
    if impulse_plots:
        Image(filename=os.path.join(viz_dir, impulse_plots[0]))
# Out:
# 2026-01-29 20:25:43 - fmu2ml.analysis.rate_of_change.visualizers.impulse_response_visualizer - INFO - Creating impulse response plots...
# Creating impulse response plots...
# 2026-01-29 20:25:46 - fmu2ml.analysis.rate_of_change.visualizers.impulse_response_visualizer - INFO - Created 50/50 individual impulse plots
# 2026-01-29 20:25:48 - fmu2ml.analysis.rate_of_change.visualizers.impulse_response_visualizer - INFO - Created impulse response summary plots

# %%
Image(filename=os.path.join(viz_dir, impulse_plots[0]))

# %%
if not response_summary_df.empty:
    print("Creating response characteristics heatmap...")
    create_response_characteristics_heatmap(response_summary_df, viz_dir)
    Image(filename=os.path.join(viz_dir, 'response_characteristics_heatmap.png'))
# Out:
# 2026-01-29 20:25:48 - fmu2ml.analysis.rate_of_change.visualizers.response_heatmap_visualizer - INFO - Creating response characteristics heatmaps...
# Creating response characteristics heatmap...
# 2026-01-29 20:25:52 - fmu2ml.analysis.rate_of_change.visualizers.response_heatmap_visualizer - INFO - Created response characteristics heatmaps

# %%
Image(filename=os.path.join(viz_dir,'response_characteristics_heatmap.png'))

# %%
#  Analysis Summary - Effect Dominance
print("="*60)
print("LEVEL VS RATE EFFECT SUMMARY")
print("="*60)

# Overall statistics
print(f"\nOverall Effect Distribution:")
for effect_type, count in level_rate_df['dominant_effect'].value_counts().items():
    pct = count / len(level_rate_df) * 100
    print(f"  {effect_type.capitalize()}: {count} ({pct:.1f}%)")

# By input
print("\nBy Input Variable:")
for input_var in ['Q_flow', 'T_Air', 'T_ext']:
    input_data = level_rate_df[level_rate_df['input'] == input_var]
    rate_dominant_pct = (input_data['dominant_effect'] == 'rate').sum() / len(input_data) * 100
    print(f"  {input_var}: {rate_dominant_pct:.1f}% rate-dominant")
# Out:
# ============================================================
# LEVEL VS RATE EFFECT SUMMARY
# ============================================================
#
# Overall Effect Distribution:
#   Level: 27 (69.2%)
#   Rate: 8 (20.5%)
#   Mixed: 4 (10.3%)
#
# By Input Variable:
#   Q_flow: 0.0% rate-dominant
#   T_Air: 15.4% rate-dominant
#   T_ext: 46.2% rate-dominant

# %%
# Analysis Summary - Response Dynamics
print("="*60)
print("RESPONSE DYNAMICS SUMMARY")
print("="*60)

print("\nResponse Lag Characteristics:")
for input_var in ['Q_flow', 'T_Air', 'T_ext']:
    input_lags = lag_df[lag_df['input'] == input_var]
    print(f"\n  {input_var}:")
    print(f"    Mean lag: {input_lags['optimal_lag'].mean():.1f} steps")
    print(f"    Median lag: {input_lags['optimal_lag'].median():.1f} steps")
    print(f"    Max lag: {input_lags['optimal_lag'].max():.0f} steps")
    print(f"    Mean correlation: {input_lags['max_correlation'].mean():.3f}")
# Out:
# ============================================================
# RESPONSE DYNAMICS SUMMARY
# ============================================================
#
# Response Lag Characteristics:
#
#   Q_flow:
#     Mean lag: 11.5 steps
#     Median lag: 30.0 steps
#     Max lag: 30 steps
#     Mean correlation: 0.083
#
#   T_Air:
#     Mean lag: 19.7 steps
#     Median lag: 30.0 steps
#     Max lag: 30 steps
#     Mean correlation: 0.012
#
#   T_ext:
#     Mean lag: -11.0 steps
#     Median lag: -27.0 steps
#     Max lag: 30 steps
#     Mean correlation: 0.028

# %%
# Analysis Summary - Impulse Response
if not response_summary_df.empty:
    print("="*60)
    print("IMPULSE RESPONSE SUMMARY")
    print("="*60)
    
    for input_var in response_summary_df['input'].unique():
        input_summary = response_summary_df[response_summary_df['input'] == input_var]
        
        print(f"\n{input_var} Impulse Characteristics:")
        print(f"  Output-input pairs: {len(input_summary)}")
        print(f"  Avg rise time: {input_summary['rise_time_mean'].mean():.1f} steps")
        print(f"  Avg settling time: {input_summary['settling_time_mean'].mean():.1f} steps")
        print(f"  Avg gain: {input_summary['gain_mean'].mean():.4f}")
        print(f"  Avg time constant: {input_summary['time_constant_mean'].mean():.1f} steps")
# Out:
# ============================================================
# IMPULSE RESPONSE SUMMARY
# ============================================================
#
# T_ext Impulse Characteristics:
#   Output-input pairs: 12
#   Avg rise time: 32.1 steps
#   Avg settling time: 56.0 steps
#   Avg gain: -0.0197
#   Avg time constant: 27.0 steps

# %%
# Modeling Recommendations
print("="*60)
print("MODELING RECOMMENDATIONS")
print("="*60)

# Check rate importance
rate_important = (level_rate_df['dominant_effect'] == 'rate').sum() / len(level_rate_df)

print("\n1. Derivative Features:")
if rate_important > 0.3:
    print("   ✓ HIGH IMPORTANCE: Include rate-of-change features")
    print(f"     {rate_important*100:.1f}% of relationships are rate-dominant")
elif rate_important > 0.1:
    print("   ⚠ MODERATE IMPORTANCE: Consider including rate features")
else:
    print("   ✗ LOW IMPORTANCE: Level features may be sufficient")

# Check temporal dependencies
avg_lag = lag_df['optimal_lag'].mean()
max_lag = lag_df['optimal_lag'].max()

print("\n2. Temporal Dependencies:")
if avg_lag > 10:
    print(f"   ✓ STRONG: Use RNN/LSTM (avg lag = {avg_lag:.1f} steps)")
elif avg_lag > 5:
    print(f"   ⚠ MODERATE: Consider sequence models or lagged features")
else:
    print(f"   ✗ WEAK: Feedforward network may suffice")

# Check response characteristics
if not response_summary_df.empty:
    avg_time_const = response_summary_df['time_constant_mean'].mean()
    print("\n3. System Dynamics:")
    print(f"   Average time constant: {avg_time_const:.1f} steps")
    if avg_time_const > 20:
        print("   → Slow dynamics: Long sequence length needed")
    elif avg_time_const > 10:
        print("   → Moderate dynamics: Medium sequence length")
    else:
        print("   → Fast dynamics: Short sequence may work")
# Out:
# ============================================================
# MODELING RECOMMENDATIONS
# ============================================================
#
# 1. Derivative Features:
#    ⚠ MODERATE IMPORTANCE: Consider including rate features
#
# 2. Temporal Dependencies:
#    ⚠ MODERATE: Consider sequence models or lagged features
#
# 3. System Dynamics:
#    Average time constant: 27.0 steps
#    → Slow dynamics: Long sequence length needed

# %%
# Save All Results
print("Saving results...")

# Save dataframes
level_rate_df.to_csv(os.path.join(OUTPUT_DIR, 'level_rate_metrics.csv'), index=False)
lag_df.to_csv(os.path.join(OUTPUT_DIR, 'lag_analysis.csv'), index=False)

if not response_df.empty:
    response_df.to_csv(os.path.join(OUTPUT_DIR, 'impulse_responses.csv'), index=False)
    response_summary_df.to_csv(os.path.join(OUTPUT_DIR, 'response_summary.csv'), index=False)

if 'dynamics_summary' in locals():
    dynamics_summary.to_csv(os.path.join(OUTPUT_DIR, 'dynamics_summary.csv'), index=False)

print(f"\nAll results saved to: {OUTPUT_DIR}")
print("\nFiles created:")
print("  - dynamic_data.parquet")
print("  - level_rate_metrics.csv")
print("  - lag_analysis.csv")
print("  - impulse_responses.csv")
print("  - response_summary.csv")
print("  - dynamics_summary.csv")
print("  - visualizations/ (multiple plots)")
# Out:
# Saving results...
#
# All results saved to: ../results/marconi100/data_analysis/io_rate_of_change
#
# Files created:
#   - dynamic_data.parquet
#   - level_rate_metrics.csv
#   - lag_analysis.csv
#   - impulse_responses.csv
#   - response_summary.csv
#   - dynamics_summary.csv
#   - visualizations/ (multiple plots)

# %%
# Cleanup
rate_analyzer._close_dask_client()
impulse_analyzer._close_dask_client()

print("\nAnalysis complete! Dask clients closed.")
