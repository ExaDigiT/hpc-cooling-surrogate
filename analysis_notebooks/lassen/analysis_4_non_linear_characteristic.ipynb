# %% [markdown]
# ## Import libraries

# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
import os, sys
from IPython.display import Image
from datetime import datetime

project_root = Path.cwd().parent.parent
sys.path.append(str(project_root))
os.chdir(project_root)


from fmu2ml.analysis.nonlinear_characterization.analyzers import (
    NonlinearAnalyzer,
    ThresholdDetector
)
from fmu2ml.analysis.nonlinear_characterization.visualizers.residual_visualizer import (
    create_residual_summary_plot
)
from fmu2ml.analysis.nonlinear_characterization.visualizers.threshold_visualizer import (
    create_threshold_summary_plot
)
from fmu2ml.analysis.nonlinear_characterization.visualizers import *
from fmu2ml.analysis.input_output_relations.analyzers import DataGenerator
from raps.config import ConfigManager

sns.set_style("whitegrid")
# %matplotlib inline

# %% [markdown]
# ## Define Parameters

# %%
# Configuration
SYSTEM_NAME = 'lassen'

SAMPLES_PER_HOUR = 60
TOTAL_TIMESTEPS = 7200
MAX_POLYNOMIAL_DEGREE = 5
MAX_BREAKPOINTS = 3
OUTPUT_DIR = f'../results/{SYSTEM_NAME}/data_analysis/nonlinear_characterization'
DATA_DIR = f'../results/{SYSTEM_NAME}/data_analysis/direct_effect_analysis'

# Load Configuration and Initialize
config = ConfigManager(system_name=SYSTEM_NAME).get_config()
# num_cdus = config.get('NUM_CDUS', 49)
num_cdus = 44

print(f"Number of CDUs: {num_cdus}")
print(f"Configuration loaded for {SYSTEM_NAME}")

os.makedirs(OUTPUT_DIR, exist_ok=True)

# Input ranges
INPUT_RANGES = {
    'Q_flow': (config.get('MIN_POWER'), config.get('MAX_POWER')),    # kW
    'T_Air': (288.15, 308.15),   # K
    'T_ext': (283.15, 313.15)    # K
}


# Parallel settings
N_WORKERS = 48
THREADS_PER_WORKER = 1
MEMORY_LIMIT = '64GB'

# Key outputs
KEY_OUTPUTS = ['T_prim_r_C', 'W_flow_CDUP_kW', 'V_flow_prim_GPM']

print(f"System: {SYSTEM_NAME}")
print(f"Max polynomial degree: {MAX_POLYNOMIAL_DEGREE}")
print(f"Max breakpoints: {MAX_BREAKPOINTS}")
print(f"Output dir: {OUTPUT_DIR}")
# Out:
# Number of CDUs: 44
# Configuration loaded for lassen
# System: lassen
# Max polynomial degree: 5
# Max breakpoints: 3
# Output dir: ../results/lassen/data_analysis/nonlinear_characterization

# %%
# Initialize Components
config_for_components = {k: v for k, v in config.items() 
                        if k not in ['system_name', 'max_polynomial_degree', 'max_breakpoints']}

# Data generator
data_generator = DataGenerator(
    system_name=SYSTEM_NAME,
    n_workers=N_WORKERS,
    **config_for_components
)

# Nonlinear analyzer
nonlinear_analyzer = NonlinearAnalyzer(
    system_name=SYSTEM_NAME,
    n_workers=N_WORKERS,
    threads_per_worker=THREADS_PER_WORKER,
    memory_limit=MEMORY_LIMIT,
    max_polynomial_degree=MAX_POLYNOMIAL_DEGREE,
    **config_for_components
)

# Threshold detector
threshold_detector = ThresholdDetector(
    system_name=SYSTEM_NAME,
    n_workers=N_WORKERS,
    threads_per_worker=THREADS_PER_WORKER,
    memory_limit=MEMORY_LIMIT,
    max_breakpoints=MAX_BREAKPOINTS,
    **config_for_components
)

print("Components initialized")
# Out:
# 2026-02-06 17:36:39 - fmu2ml.analysis.input_output_relations.analyzers.data_generator - INFO - DataGenerator initialized for system: lassen
# 2026-02-06 17:36:39 - fmu2ml.analysis.input_output_relations.analyzers.data_generator - INFO - Number of CDUs: 44
# 2026-02-06 17:36:39 - fmu2ml.analysis.nonlinear_characterization.analyzers.nonlinear_analyzer - INFO - NonlinearAnalyzer initialized for system: lassen
# 2026-02-06 17:36:39 - fmu2ml.analysis.nonlinear_characterization.analyzers.nonlinear_analyzer - INFO - Number of CDUs: 44
# 2026-02-06 17:36:39 - fmu2ml.analysis.nonlinear_characterization.analyzers.nonlinear_analyzer - INFO - Max polynomial degree: 5
# 2026-02-06 17:36:39 - fmu2ml.analysis.nonlinear_characterization.analyzers.threshold_detector - INFO - ThresholdDetector initialized for system: lassen
# 2026-02-06 17:36:39 - fmu2ml.analysis.nonlinear_characterization.analyzers.threshold_detector - INFO - Max breakpoints: 3
# Components initialized

# %% [markdown]
# ## Load / Generate Data

# %%
data_file = os.path.join(DATA_DIR, 'sensitivity_data.parquet')

data = None
if os.path.exists(data_file):
    print("Loading simulation data...")
    data = pd.read_parquet(data_file)
else:
    print("Generating simulation data...")
    # Generate Data
    data = data_generator.generate_sensitivity_data(
        n_samples=N_SAMPLES,
        input_ranges=INPUT_RANGES
    )
    
    # Save data
    data.to_parquet(data_file)
    print(f"Data saved to: {data_file}")

print(f"Data shape: {data.shape}")
# Out:
# Loading simulation data...
# Data shape: (7200, 1105)

# %%
# Prepare Data
prepared_data = nonlinear_analyzer.prepare_data(data)
print(f"Data prepared. Shape: {len(prepared_data['inputs'])} samples")
print(f"Input variables: {nonlinear_analyzer.input_vars}")
print(f"Output variables (first 5): {list(prepared_data['outputs'].keys())[:5]}")
# Out:
# 2026-02-06 17:36:39 - fmu2ml.analysis.nonlinear_characterization.analyzers.nonlinear_analyzer - INFO - Preparing data for non-linear analysis...
# 2026-02-06 17:36:39 - fmu2ml.analysis.nonlinear_characterization.analyzers.nonlinear_analyzer - INFO - Data prepared: 3 inputs, 12 CDU outputs, 2 datacenter outputs
# Data prepared. Shape: 3 samples
# Input variables: ['Q_flow', 'T_Air', 'T_ext']
# Output variables (first 5): ['V_flow_prim_GPM', 'V_flow_sec_GPM', 'W_flow_CDUP_kW', 'T_prim_s_C', 'T_prim_r_C']

# %% [markdown]
# ## 1. Polynomial Fit Analysis

# %%
# Polynomial Fitting Analysis
print("Analyzing polynomial fits...")
polynomial_df, polynomial_full_results = nonlinear_analyzer.analyze_polynomial_fits(prepared_data)

print(f"\nTotal relationships analyzed: {len(polynomial_df)}")
print(f"\nBest polynomial degrees:")
print(polynomial_df['best_degree'].value_counts().sort_index())
# Out:
# 2026-02-06 17:36:39 - fmu2ml.analysis.nonlinear_characterization.analyzers.nonlinear_analyzer - INFO - Computing polynomial fits for all input-output pairs...
# 2026-02-06 17:36:39 - fmu2ml.analysis.nonlinear_characterization.analyzers.nonlinear_analyzer - INFO - Initializing Dask cluster for non-linear analysis...
# Analyzing polynomial fits...
# 2026-02-06 17:36:39 - distributed.scheduler - INFO - State start
# 2026-02-06 17:36:39 - distributed.scheduler - INFO -   Scheduler at:     tcp://127.0.0.1:40803
# 2026-02-06 17:36:39 - distributed.scheduler - INFO -   dashboard at:  http://127.0.0.1:37351/status
# 2026-02-06 17:36:39 - distributed.scheduler - INFO - Registering Worker plugin shuffle
# 2026-02-06 17:36:40 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:34555'
# 2026-02-06 17:36:40 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:33059'
# 2026-02-06 17:36:40 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:41549'
# 2026-02-06 17:36:40 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:45787'
# 2026-02-06 17:36:40 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:42677'
# 2026-02-06 17:36:40 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:39201'
# 2026-02-06 17:36:40 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:45931'
# 2026-02-06 17:36:40 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:41019'
# 2026-02-06 17:36:40 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:46451'
# 2026-02-06 17:36:40 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:44533'
# 2026-02-06 17:36:40 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:41967'
# 2026-02-06 17:36:40 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:39841'
# 2026-02-06 17:36:40 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:46261'
# 2026-02-06 17:36:40 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:35471'
# 2026-02-06 17:36:40 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:35669'
# 2026-02-06 17:36:40 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:45747'
# 2026-02-06 17:36:40 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:36349'
# 2026-02-06 17:36:40 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:45813'
# 2026-02-06 17:36:40 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:43365'
# 2026-02-06 17:36:40 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:41179'
# 2026-02-06 17:36:40 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:35611'
# 2026-02-06 17:36:40 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:46849'
# 2026-02-06 17:36:40 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:34175'
# 2026-02-06 17:36:40 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:40945'
# 2026-02-06 17:36:40 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:36649'
# 2026-02-06 17:36:40 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:43911'
# 2026-02-06 17:36:40 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:36699'
# 2026-02-06 17:36:40 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:37827'
# 2026-02-06 17:36:40 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:42975'
# 2026-02-06 17:36:40 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:35757'
# 2026-02-06 17:36:40 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:44273'
# 2026-02-06 17:36:40 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:46285'
# 2026-02-06 17:36:40 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:37079'
# 2026-02-06 17:36:40 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:38401'
# 2026-02-06 17:36:40 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:40257'
# 2026-02-06 17:36:40 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:42855'
# 2026-02-06 17:36:40 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:32981'
# 2026-02-06 17:36:40 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:34447'
# 2026-02-06 17:36:40 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:36065'
# 2026-02-06 17:36:40 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:35829'
# 2026-02-06 17:36:40 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:40683'
# 2026-02-06 17:36:40 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:34427'
# 2026-02-06 17:36:40 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:42699'
# 2026-02-06 17:36:40 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:38467'
# 2026-02-06 17:36:40 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:45727'
# 2026-02-06 17:36:40 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:40077'
# 2026-02-06 17:36:40 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:46599'
# 2026-02-06 17:36:40 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:36423'
# 2026-02-06 17:36:40 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:36399 name: 1
# 2026-02-06 17:36:40 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:36399
# 2026-02-06 17:36:40 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:41466
# 2026-02-06 17:36:41 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:44377 name: 0
# 2026-02-06 17:36:41 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:44377
# 2026-02-06 17:36:41 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:41474
# 2026-02-06 17:36:41 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:37977 name: 5
# 2026-02-06 17:36:41 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:37977
# 2026-02-06 17:36:41 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:41482
# 2026-02-06 17:36:41 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:35411 name: 7
# 2026-02-06 17:36:41 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:35411
# 2026-02-06 17:36:41 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:41492
# 2026-02-06 17:36:41 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:40245 name: 3
# 2026-02-06 17:36:41 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:40245
# 2026-02-06 17:36:41 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:41498
# 2026-02-06 17:36:41 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:32921 name: 4
# 2026-02-06 17:36:41 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:32921
# 2026-02-06 17:36:41 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:41508
# 2026-02-06 17:36:41 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:42755 name: 2
# 2026-02-06 17:36:41 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:42755
# 2026-02-06 17:36:41 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:41524
# 2026-02-06 17:36:41 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:39503 name: 6
# 2026-02-06 17:36:41 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:39503
# 2026-02-06 17:36:41 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:41536
# 2026-02-06 17:36:41 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:40811 name: 8
# 2026-02-06 17:36:41 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:40811
# 2026-02-06 17:36:41 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:41544
# 2026-02-06 17:36:41 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:34439 name: 9
# 2026-02-06 17:36:41 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:34439
# 2026-02-06 17:36:41 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:41560
# 2026-02-06 17:36:41 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:42785 name: 12
# 2026-02-06 17:36:41 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:42785
# 2026-02-06 17:36:41 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:41564
# 2026-02-06 17:36:41 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:39507 name: 14
# 2026-02-06 17:36:41 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:39507
# 2026-02-06 17:36:41 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:41574
# 2026-02-06 17:36:41 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:42977 name: 18
# 2026-02-06 17:36:41 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:42977
# 2026-02-06 17:36:41 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:41578
# 2026-02-06 17:36:41 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:35523 name: 11
# 2026-02-06 17:36:41 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:35523
# 2026-02-06 17:36:41 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:41582
# 2026-02-06 17:36:41 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:45073 name: 16
# 2026-02-06 17:36:41 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:45073
# 2026-02-06 17:36:41 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:41594
# 2026-02-06 17:36:41 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:40281 name: 17
# 2026-02-06 17:36:41 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:40281
# 2026-02-06 17:36:41 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:41590
# 2026-02-06 17:36:41 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:46089 name: 10
# 2026-02-06 17:36:41 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:46089
# 2026-02-06 17:36:41 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:41602
# 2026-02-06 17:36:41 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:38999 name: 15
# 2026-02-06 17:36:41 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:38999
# 2026-02-06 17:36:41 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:41618
# 2026-02-06 17:36:41 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:37963 name: 13
# 2026-02-06 17:36:41 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:37963
# 2026-02-06 17:36:41 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:41632
# 2026-02-06 17:36:41 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:33717 name: 23
# 2026-02-06 17:36:41 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:33717
# 2026-02-06 17:36:41 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:41646
# 2026-02-06 17:36:41 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:35175 name: 20
# 2026-02-06 17:36:41 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:35175
# 2026-02-06 17:36:41 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:41658
# 2026-02-06 17:36:41 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:42069 name: 27
# 2026-02-06 17:36:41 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:42069
# 2026-02-06 17:36:41 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:41668
# 2026-02-06 17:36:41 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:46293 name: 21
# 2026-02-06 17:36:41 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:46293
# 2026-02-06 17:36:41 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:41672
# 2026-02-06 17:36:41 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:39969 name: 25
# 2026-02-06 17:36:41 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:39969
# 2026-02-06 17:36:41 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:41688
# 2026-02-06 17:36:41 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:44227 name: 29
# 2026-02-06 17:36:41 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:44227
# 2026-02-06 17:36:41 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:41690
# 2026-02-06 17:36:41 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:35955 name: 33
# 2026-02-06 17:36:41 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:35955
# 2026-02-06 17:36:41 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:41702
# 2026-02-06 17:36:41 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:45075 name: 28
# 2026-02-06 17:36:41 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:45075
# 2026-02-06 17:36:41 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:41716
# 2026-02-06 17:36:41 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:43821 name: 24
# 2026-02-06 17:36:41 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:43821
# 2026-02-06 17:36:41 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:41722
# 2026-02-06 17:36:41 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:45519 name: 19
# 2026-02-06 17:36:41 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:45519
# 2026-02-06 17:36:41 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:41734
# 2026-02-06 17:36:41 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:42191 name: 22
# 2026-02-06 17:36:41 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:42191
# 2026-02-06 17:36:41 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:41736
# 2026-02-06 17:36:41 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:44481 name: 26
# 2026-02-06 17:36:41 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:44481
# 2026-02-06 17:36:41 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:41738
# 2026-02-06 17:36:41 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:33457 name: 32
# 2026-02-06 17:36:41 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:33457
# 2026-02-06 17:36:41 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:41740
# 2026-02-06 17:36:41 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:41321 name: 30
# 2026-02-06 17:36:41 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:41321
# 2026-02-06 17:36:41 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:41764
# 2026-02-06 17:36:41 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:36453 name: 31
# 2026-02-06 17:36:41 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:36453
# 2026-02-06 17:36:41 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:41750
# 2026-02-06 17:36:41 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:34311 name: 36
# 2026-02-06 17:36:41 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:34311
# 2026-02-06 17:36:41 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:41780
# 2026-02-06 17:36:41 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:38409 name: 37
# 2026-02-06 17:36:41 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:38409
# 2026-02-06 17:36:41 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:41782
# 2026-02-06 17:36:41 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:40715 name: 35
# 2026-02-06 17:36:41 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:40715
# 2026-02-06 17:36:41 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:41790
# 2026-02-06 17:36:41 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:34479 name: 38
# 2026-02-06 17:36:41 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:34479
# 2026-02-06 17:36:41 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:41802
# 2026-02-06 17:36:41 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:40067 name: 39
# 2026-02-06 17:36:41 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:40067
# 2026-02-06 17:36:41 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:41808
# 2026-02-06 17:36:41 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:44479 name: 34
# 2026-02-06 17:36:41 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:44479
# 2026-02-06 17:36:41 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:41818
# 2026-02-06 17:36:41 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:45389 name: 40
# 2026-02-06 17:36:41 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:45389
# 2026-02-06 17:36:41 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:41830
# 2026-02-06 17:36:41 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:42281 name: 42
# 2026-02-06 17:36:41 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:42281
# 2026-02-06 17:36:41 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:41840
# 2026-02-06 17:36:41 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:40207 name: 44
# 2026-02-06 17:36:41 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:40207
# 2026-02-06 17:36:41 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:41848
# 2026-02-06 17:36:41 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:35741 name: 47
# 2026-02-06 17:36:41 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:35741
# 2026-02-06 17:36:41 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:41862
# 2026-02-06 17:36:41 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:41041 name: 43
# 2026-02-06 17:36:41 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:41041
# 2026-02-06 17:36:41 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:41872
# 2026-02-06 17:36:41 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:40159 name: 46
# 2026-02-06 17:36:41 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:40159
# 2026-02-06 17:36:41 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:41882
# 2026-02-06 17:36:41 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:33505 name: 41
# 2026-02-06 17:36:41 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:33505
# 2026-02-06 17:36:41 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:41898
# 2026-02-06 17:36:41 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:39379 name: 45
# 2026-02-06 17:36:41 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:39379
# 2026-02-06 17:36:41 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:41902
# 2026-02-06 17:36:41 - distributed.scheduler - INFO - Receive client connection: Client-4ebfe212-03ac-11f1-9486-0a580a221712
# 2026-02-06 17:36:41 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:41908
# 2026-02-06 17:36:41 - fmu2ml.analysis.nonlinear_characterization.analyzers.nonlinear_analyzer - INFO - Dask client initialized: http://127.0.0.1:37351/status
# 2026-02-06 17:36:41 - fmu2ml.analysis.nonlinear_characterization.analyzers.nonlinear_analyzer - INFO - Executing 42 polynomial fit tasks in parallel...
# 2026-02-06 17:36:51 - fmu2ml.analysis.nonlinear_characterization.analyzers.nonlinear_analyzer - INFO - Computed polynomial fits for 42 pairs
# Total relationships analyzed: 42
#
# Best polynomial degrees:
# best_degree
# 1    40
# 2     1
# 3     1
# Name: count, dtype: int64
# 2026-02-06 17:37:42 - distributed.scheduler - INFO - Remove client Client-4ebfe212-03ac-11f1-9486-0a580a221712
# 2026-02-06 17:37:42 - distributed.core - INFO - Received 'close-stream' from tcp://127.0.0.1:41908; closing.
# 2026-02-06 17:37:42 - distributed.scheduler - INFO - Remove client Client-4ebfe212-03ac-11f1-9486-0a580a221712
# 2026-02-06 17:37:42 - distributed.scheduler - INFO - Close client connection: Client-4ebfe212-03ac-11f1-9486-0a580a221712

# %%
# Display top improvements
top_poly = polynomial_df.nlargest(20, 'best_r2')
print("\nTop 20 Best Polynomial Fits:")
print(top_poly[['input', 'output', 'r2_degree_1','r2_degree_2', 'best_r2', 'best_degree', 'nonlinearity_strength']])
# Out:
# Top 20 Best Polynomial Fits:
#      input                      output   r2_degree_1  r2_degree_2   best_r2  \
# 11  Q_flow                         htc  1.000000e+00     1.000000  1.000000
# 25   T_Air                         htc  1.000000e+00     1.000000  1.000000
# 39   T_ext                         htc  1.000000e+00     1.000000  1.000000
# 13  Q_flow                         pue  9.964831e-01     0.998918  0.998620
# 9   Q_flow                p_sec_s_psig  5.985707e-01     0.598583  0.555847
# 10  Q_flow                p_sec_r_psig  5.985431e-01     0.598556  0.555811
# 1   Q_flow              V_flow_sec_GPM  4.727794e-01     0.472866  0.394552
# 0   Q_flow             V_flow_prim_GPM  4.720221e-06     0.000019  0.000000
# 2   Q_flow              W_flow_CDUP_kW  1.001578e-03     0.001419  0.000000
# 3   Q_flow                  T_prim_s_C  5.608133e-05     0.000231  0.000000
# 4   Q_flow                  T_prim_r_C  4.565815e-04     0.000458  0.000000
# 5   Q_flow                   T_sec_s_C  1.267202e-03     0.001683  0.000000
# 6   Q_flow                   T_sec_r_C  5.190522e-03     0.005607  0.000000
# 7   Q_flow               p_prim_s_psig  4.229391e-07     0.000063  0.000000
# 8   Q_flow               p_prim_r_psig  6.387092e-10     0.000068  0.000000
# 12  Q_flow  V_flow_prim_GPM_datacenter  9.473642e-08     0.025592  0.000000
# 14   T_Air             V_flow_prim_GPM  3.993843e-04     0.000421  0.000000
# 15   T_Air              V_flow_sec_GPM  3.978341e-04     0.000409  0.000000
# 16   T_Air              W_flow_CDUP_kW  1.998202e-04     0.000201  0.000000
# 17   T_Air                  T_prim_s_C  1.048435e-03     0.001054  0.000000
#
#     best_degree  nonlinearity_strength
# 11            1               0.000000
# 25            1               0.000000
# 39            1               0.000000
# 13            2               0.244636
# 9             1               0.003158
# 10            1               0.003158
# 1             3               0.030494
# 0             1               0.006573
# 2             1               0.053151
# 3             1               0.039316
# 4             1               0.006457
# 5             1               0.052969
# 6             1               0.053145
# 7             1               0.019624
# 8             1               0.022030
# 12            1               2.614159
# 14            1               0.062358
# 15            1               0.012198
# 16            1               0.028780
# 17            1               0.015390

# %%
# #  Model Comparison - Linear vs Polynomial
print("Computing model comparisons...")
comparison_df = nonlinear_analyzer.compute_model_comparison(prepared_data)

print(f"\nComparisons computed: {len(comparison_df)}")


# R² improvement analysis
comparison_df['r2_improvement_pct'] = (
    (comparison_df['best_nonlinear_r2'] - comparison_df['linear_r2']) / 
    (comparison_df['linear_r2'] + 1e-10) * 100
)

print("\nR² Improvement Distribution:")
print(comparison_df['r2_improvement_pct'].describe())

# Strongly nonlinear relationships
strongly_nonlinear = comparison_df[comparison_df['r2_improvement_pct'] > 5]
print(f"\nStrongly nonlinear relationships (>5% improvement): {len(strongly_nonlinear)}")

if not strongly_nonlinear.empty:
    print("\nTop 5 Most Nonlinear:")
    top_nonlinear = strongly_nonlinear.nlargest(5, 'r2_improvement_pct')
    print(top_nonlinear[['input', 'output', 'r2_improvement_pct', 'best_degree']])
# Out:
# 2026-02-06 17:36:51 - fmu2ml.analysis.nonlinear_characterization.analyzers.nonlinear_analyzer - INFO - Computing model comparison (linear vs. non-linear)...
# 2026-02-06 17:36:51 - fmu2ml.analysis.nonlinear_characterization.analyzers.nonlinear_analyzer - INFO - Computing polynomial fits for all input-output pairs...
# 2026-02-06 17:36:51 - fmu2ml.analysis.nonlinear_characterization.analyzers.nonlinear_analyzer - INFO - Executing 42 polynomial fit tasks in parallel...
# Computing model comparisons...
# 2026-02-06 17:36:58 - fmu2ml.analysis.nonlinear_characterization.analyzers.nonlinear_analyzer - INFO - Computed polynomial fits for 42 pairs
# 2026-02-06 17:36:58 - fmu2ml.analysis.nonlinear_characterization.analyzers.nonlinear_analyzer - INFO - Computed comparison for 42 pairs
# Comparisons computed: 42
#
# R² Improvement Distribution:
# count    4.200000e+01
# mean     1.354047e+06
# std      6.129711e+06
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      1.973580e+01
# 75%      1.469049e+02
# max      2.982163e+07
# Name: r2_improvement_pct, dtype: float64
#
# Strongly nonlinear relationships (>5% improvement): 24
#
# Top 5 Most Nonlinear:
#      input                      output  r2_improvement_pct  best_degree
# 8   Q_flow               p_prim_r_psig        2.982163e+07            5
# 12  Q_flow  V_flow_prim_GPM_datacenter        2.698482e+07            2
# 7   Q_flow               p_prim_s_psig        4.638853e+04            5
# 27   T_Air                         pue        1.343733e+04            5
# 0   Q_flow             V_flow_prim_GPM        1.317246e+03            3

# %%
# Polynomial Analysis by Input
for input_var in ['Q_flow', 'T_Air', 'T_ext']:
    input_data = comparison_df[comparison_df['input'] == input_var]
    
    print(f"\n{input_var} Analysis:")
    print(f"  Relationships: {len(input_data)}")
    print(f"  Mean R² (linear): {input_data['linear_r2'].mean():.4f}")
    print(f"  Mean R² (best poly): {input_data['best_nonlinear_r2'].mean():.4f}")
    print(f"  Mean improvement: {input_data['r2_improvement_pct'].mean():.2f}%")
    print(f"  Most common degree: {input_data['best_degree'].mode()[0] if not input_data.empty else 'N/A'}")
# Out:
# Q_flow Analysis:
#   Relationships: 14
#   Mean R² (linear): 0.2625
#   Mean R² (best poly): 0.2647
#   Mean improvement: 4061069.35%
#   Most common degree: 5
#
# T_Air Analysis:
#   Relationships: 14
#   Mean R² (linear): 0.0784
#   Mean R² (best poly): 0.0840
#   Mean improvement: 1046.32%
#   Most common degree: 5
#
# T_ext Analysis:
#   Relationships: 14
#   Mean R² (linear): 0.0725
#   Mean R² (best poly): 0.0745
#   Mean improvement: 25.04%
#   Most common degree: 1

# %%
# Generate Prediction Data for Visualization
print("Generating prediction data...")
prediction_data_dict = {}

all_outputs = list(prepared_data['outputs'].keys())
if 'datacenter_outputs' in prepared_data:
    all_outputs.extend(prepared_data['datacenter_outputs'].keys())

# Get predictions for key relationships
for input_name in nonlinear_analyzer.input_vars:
    for output_name in KEY_OUTPUTS:
        if output_name in all_outputs:
            pred_data = nonlinear_analyzer.get_prediction_data(
                prepared_data, input_name, output_name,
                degrees=[1, 2, 3, 4]
            )
            if pred_data:
                prediction_data_dict[(input_name, output_name)] = pred_data

print(f"Prediction data generated for {len(prediction_data_dict)} pairs")
# Out:
# Generating prediction data...
# Prediction data generated for 9 pairs

# %%
# Visualize Polynomial Fits
viz_dir = os.path.join(OUTPUT_DIR, 'visualizations', 'polynomial')
os.makedirs(viz_dir, exist_ok=True)

print("Creating polynomial fit visualizations...")
create_nonlinearity_plots(
    prediction_data_dict,
    viz_dir,
    n_workers=N_WORKERS
)
# Out:
# 2026-02-06 17:36:59 - fmu2ml.analysis.nonlinear_characterization.visualizers.nonlinearity_visualizer - INFO - Creating nonlinearity plots in parallel...
# Creating polynomial fit visualizations...
# 2026-02-06 17:37:01 - fmu2ml.analysis.nonlinear_characterization.visualizers.nonlinearity_visualizer - INFO - Created 9/9 nonlinearity plots

# %%
from IPython.display import Image

# Display example
poly_plots = [f for f in os.listdir(viz_dir) if f.startswith('nonlinearity_')]
Image(filename=os.path.join(viz_dir, poly_plots[3]))

# %%
# Model Comparison Plots
create_model_comparison_plots(comparison_df, polynomial_df, viz_dir)
# Image(filename=os.path.join(viz_dir, 'r2_comparison_heatmap.png'))
# Image(filename=os.path.join(viz_dir, 'degree_r2_heatmap.png'))
Image(filename=os.path.join(viz_dir, 'best_degree_distribution.png'))

#
# Out:
# 2026-02-06 17:37:01 - fmu2ml.analysis.nonlinear_characterization.visualizers.model_comparison_visualizer - INFO - Creating model comparison plots...
# 2026-02-06 17:37:11 - fmu2ml.analysis.nonlinear_characterization.visualizers.model_comparison_visualizer - INFO - Created model comparison plots

# %%
# Residual Analysis
residual_dir = os.path.join(OUTPUT_DIR, 'visualizations', 'residuals')
os.makedirs(residual_dir, exist_ok=True)

print("Creating residual plots...")
create_residual_plots(
    prediction_data_dict,
    residual_dir,
    n_workers=N_WORKERS
)

create_residual_summary_plot(prediction_data_dict, residual_dir)
Image(filename=os.path.join(residual_dir, 'residual_summary.png'))
# Out:
# 2026-02-06 17:37:11 - fmu2ml.analysis.nonlinear_characterization.visualizers.residual_visualizer - INFO - Creating residual plots in parallel...
# Creating residual plots...
# 2026-02-06 17:37:15 - fmu2ml.analysis.nonlinear_characterization.visualizers.residual_visualizer - INFO - Created 9/9 residual plots
# 2026-02-06 17:37:15 - fmu2ml.analysis.nonlinear_characterization.visualizers.residual_visualizer - INFO - Creating residual summary plot...

# %%
Image(filename=os.path.join(residual_dir, 'residuals_T_ext_V_flow_prim_GPM.png'))

# %% [markdown]
# ## 2. Non-linearity Characterization Analysis

# %%
from fmu2ml.analysis.nonlinear_characterization.visualizers.strength_chart_visualizer import (
    create_neural_network_recommendations
)

# %%
# Nonlinearity Strength Chart
strength_dir = os.path.join(OUTPUT_DIR, 'visualizations', 'nonlinearity_strength')
os.makedirs(strength_dir, exist_ok=True)

create_nonlinearity_strength_chart(comparison_df, strength_dir)
create_neural_network_recommendations(comparison_df, strength_dir)

Image(filename=os.path.join(strength_dir, 'nonlinearity_strength_by_input.png'))
# Out:
# 2026-02-06 17:37:17 - fmu2ml.analysis.nonlinear_characterization.visualizers.strength_chart_visualizer - INFO - Creating non-linearity strength chart...
# 2026-02-06 17:37:17 - fmu2ml.analysis.nonlinear_characterization.visualizers.strength_chart_visualizer - WARNING - Maximum R² improvement is 29821625.9 pp, which exceeds 100 pp. This suggests R² values were not properly clamped. Values will be capped at 100 pp for visualization.
# 2026-02-06 17:37:24 - fmu2ml.analysis.nonlinear_characterization.visualizers.strength_chart_visualizer - INFO - Debug R² summary: 0 pairs with negative linear R², 0 pairs with negative best nonlinear R²
# 2026-02-06 17:37:24 - fmu2ml.analysis.nonlinear_characterization.visualizers.strength_chart_visualizer - INFO - Created non-linearity strength charts
# 2026-02-06 17:37:24 - fmu2ml.analysis.nonlinear_characterization.visualizers.strength_chart_visualizer - INFO - Creating neural network recommendations...
# 2026-02-06 17:37:25 - fmu2ml.analysis.nonlinear_characterization.visualizers.strength_chart_visualizer - INFO - Created neural network recommendations

# %%
#  Threshold Detection
print("Detecting thresholds and breakpoints...")
threshold_df, threshold_full_results = threshold_detector.detect_thresholds_all_pairs(prepared_data)

print(f"\nRelationships analyzed: {len(threshold_df)}")
print(f"Thresholds detected: {threshold_df['has_threshold'].sum()}")
print(f"Saturation detected: {threshold_df['has_saturation'].sum()}")

# Display threshold results
threshold_pairs = threshold_df[threshold_df['has_threshold']]
print(f"\nPairs with Thresholds ({len(threshold_pairs)}):")
threshold_pairs
# Out:
# 2026-02-06 17:37:25 - fmu2ml.analysis.nonlinear_characterization.analyzers.threshold_detector - INFO - Detecting thresholds for all input-output pairs...
# 2026-02-06 17:37:25 - fmu2ml.analysis.nonlinear_characterization.analyzers.threshold_detector - INFO - Initializing Dask cluster for threshold detection...
# 2026-02-06 17:37:25 - distributed.scheduler - INFO - State start
# 2026-02-06 17:37:25 - distributed.scheduler - INFO -   Scheduler at:     tcp://127.0.0.1:42767
# 2026-02-06 17:37:25 - distributed.scheduler - INFO -   dashboard at:  http://127.0.0.1:37127/status
# 2026-02-06 17:37:25 - distributed.scheduler - INFO - Registering Worker plugin shuffle
# Detecting thresholds and breakpoints...
# 2026-02-06 17:37:25 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:34357'
# 2026-02-06 17:37:25 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:42497'
# 2026-02-06 17:37:25 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:38281'
# 2026-02-06 17:37:25 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:45047'
# 2026-02-06 17:37:25 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:46787'
# 2026-02-06 17:37:25 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:34095'
# 2026-02-06 17:37:25 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:37841'
# 2026-02-06 17:37:25 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:46405'
# 2026-02-06 17:37:25 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:35271'
# 2026-02-06 17:37:25 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:37873'
# 2026-02-06 17:37:25 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:34709'
# 2026-02-06 17:37:25 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:37063'
# 2026-02-06 17:37:25 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:44423'
# 2026-02-06 17:37:25 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:41571'
# 2026-02-06 17:37:25 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:36985'
# 2026-02-06 17:37:25 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:38463'
# 2026-02-06 17:37:25 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:36089'
# 2026-02-06 17:37:25 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:38279'
# 2026-02-06 17:37:25 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:38739'
# 2026-02-06 17:37:25 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:32913'
# 2026-02-06 17:37:25 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:44851'
# 2026-02-06 17:37:26 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:41873'
# 2026-02-06 17:37:26 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:41273'
# 2026-02-06 17:37:26 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:38611'
# 2026-02-06 17:37:26 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:42001'
# 2026-02-06 17:37:26 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:45071'
# 2026-02-06 17:37:26 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:39141'
# 2026-02-06 17:37:26 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:35007'
# 2026-02-06 17:37:26 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:46679'
# 2026-02-06 17:37:26 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:41799'
# 2026-02-06 17:37:26 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:33445'
# 2026-02-06 17:37:26 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:43389'
# 2026-02-06 17:37:26 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:46333'
# 2026-02-06 17:37:26 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:35379'
# 2026-02-06 17:37:26 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:42091'
# 2026-02-06 17:37:26 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:39065'
# 2026-02-06 17:37:26 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:42849'
# 2026-02-06 17:37:26 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:43217'
# 2026-02-06 17:37:26 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:45407'
# 2026-02-06 17:37:26 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:39021'
# 2026-02-06 17:37:26 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:38621'
# 2026-02-06 17:37:26 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:43923'
# 2026-02-06 17:37:26 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:46055'
# 2026-02-06 17:37:26 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:44023'
# 2026-02-06 17:37:26 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:34177'
# 2026-02-06 17:37:26 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:43747'
# 2026-02-06 17:37:26 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:40749'
# 2026-02-06 17:37:26 - distributed.nanny - INFO -         Start Nanny at: 'tcp://127.0.0.1:41269'
# 2026-02-06 17:37:26 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:36687 name: 3
# 2026-02-06 17:37:26 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:36687
# 2026-02-06 17:37:26 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:35374
# 2026-02-06 17:37:26 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:38627 name: 2
# 2026-02-06 17:37:26 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:38627
# 2026-02-06 17:37:26 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:35388
# 2026-02-06 17:37:26 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:41003 name: 0
# 2026-02-06 17:37:26 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:41003
# 2026-02-06 17:37:26 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:35390
# 2026-02-06 17:37:26 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:33061 name: 5
# 2026-02-06 17:37:26 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:33061
# 2026-02-06 17:37:26 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:35402
# 2026-02-06 17:37:26 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:43971 name: 1
# 2026-02-06 17:37:26 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:43971
# 2026-02-06 17:37:26 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:35414
# 2026-02-06 17:37:26 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:40293 name: 6
# 2026-02-06 17:37:26 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:40293
# 2026-02-06 17:37:26 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:35428
# 2026-02-06 17:37:26 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:40103 name: 4
# 2026-02-06 17:37:26 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:40103
# 2026-02-06 17:37:26 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:35430
# 2026-02-06 17:37:26 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:32931 name: 9
# 2026-02-06 17:37:26 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:32931
# 2026-02-06 17:37:26 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:35442
# 2026-02-06 17:37:26 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:44555 name: 8
# 2026-02-06 17:37:26 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:44555
# 2026-02-06 17:37:26 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:35444
# 2026-02-06 17:37:26 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:40415 name: 11
# 2026-02-06 17:37:26 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:40415
# 2026-02-06 17:37:26 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:35448
# 2026-02-06 17:37:26 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:33955 name: 10
# 2026-02-06 17:37:26 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:33955
# 2026-02-06 17:37:26 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:35458
# 2026-02-06 17:37:26 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:45099 name: 12
# 2026-02-06 17:37:26 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:45099
# 2026-02-06 17:37:26 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:35472
# 2026-02-06 17:37:26 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:38495 name: 7
# 2026-02-06 17:37:26 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:38495
# 2026-02-06 17:37:26 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:35484
# 2026-02-06 17:37:26 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:38509 name: 13
# 2026-02-06 17:37:26 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:38509
# 2026-02-06 17:37:26 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:35494
# 2026-02-06 17:37:26 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:39655 name: 15
# 2026-02-06 17:37:26 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:39655
# 2026-02-06 17:37:26 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:35500
# 2026-02-06 17:37:26 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:38429 name: 14
# 2026-02-06 17:37:26 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:38429
# 2026-02-06 17:37:26 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:35514
# 2026-02-06 17:37:26 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:42351 name: 16
# 2026-02-06 17:37:26 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:42351
# 2026-02-06 17:37:26 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:35528
# 2026-02-06 17:37:27 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:45871 name: 18
# 2026-02-06 17:37:27 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:45871
# 2026-02-06 17:37:27 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:35534
# 2026-02-06 17:37:27 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:39295 name: 19
# 2026-02-06 17:37:27 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:39295
# 2026-02-06 17:37:27 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:35540
# 2026-02-06 17:37:27 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:39381 name: 21
# 2026-02-06 17:37:27 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:39381
# 2026-02-06 17:37:27 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:35556
# 2026-02-06 17:37:27 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:46593 name: 17
# 2026-02-06 17:37:27 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:46593
# 2026-02-06 17:37:27 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:35562
# 2026-02-06 17:37:27 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:37617 name: 22
# 2026-02-06 17:37:27 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:37617
# 2026-02-06 17:37:27 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:35574
# 2026-02-06 17:37:27 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:37103 name: 20
# 2026-02-06 17:37:27 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:37103
# 2026-02-06 17:37:27 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:35604
# 2026-02-06 17:37:27 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:41641 name: 24
# 2026-02-06 17:37:27 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:41641
# 2026-02-06 17:37:27 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:35590
# 2026-02-06 17:37:27 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:33389 name: 23
# 2026-02-06 17:37:27 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:33389
# 2026-02-06 17:37:27 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:35616
# 2026-02-06 17:37:27 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:38533 name: 26
# 2026-02-06 17:37:27 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:38533
# 2026-02-06 17:37:27 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:35628
# 2026-02-06 17:37:27 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:42835 name: 25
# 2026-02-06 17:37:27 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:42835
# 2026-02-06 17:37:27 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:35636
# 2026-02-06 17:37:27 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:37803 name: 27
# 2026-02-06 17:37:27 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:37803
# 2026-02-06 17:37:27 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:35658
# 2026-02-06 17:37:27 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:42749 name: 28
# 2026-02-06 17:37:27 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:42749
# 2026-02-06 17:37:27 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:35652
# 2026-02-06 17:37:27 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:41575 name: 31
# 2026-02-06 17:37:27 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:41575
# 2026-02-06 17:37:27 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:35672
# 2026-02-06 17:37:27 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:45993 name: 32
# 2026-02-06 17:37:27 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:45993
# 2026-02-06 17:37:27 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:35688
# 2026-02-06 17:37:27 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:46467 name: 29
# 2026-02-06 17:37:27 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:46467
# 2026-02-06 17:37:27 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:35692
# 2026-02-06 17:37:27 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:36459 name: 34
# 2026-02-06 17:37:27 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:36459
# 2026-02-06 17:37:27 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:35696
# 2026-02-06 17:37:27 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:41705 name: 30
# 2026-02-06 17:37:27 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:41705
# 2026-02-06 17:37:27 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:35714
# 2026-02-06 17:37:27 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:34753 name: 35
# 2026-02-06 17:37:27 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:34753
# 2026-02-06 17:37:27 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:35712
# 2026-02-06 17:37:27 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:34847 name: 36
# 2026-02-06 17:37:27 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:34847
# 2026-02-06 17:37:27 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:35740
# 2026-02-06 17:37:27 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:44269 name: 33
# 2026-02-06 17:37:27 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:44269
# 2026-02-06 17:37:27 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:35730
# 2026-02-06 17:37:27 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:37287 name: 37
# 2026-02-06 17:37:27 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:37287
# 2026-02-06 17:37:27 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:35752
# 2026-02-06 17:37:27 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:40175 name: 40
# 2026-02-06 17:37:27 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:40175
# 2026-02-06 17:37:27 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:35760
# 2026-02-06 17:37:27 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:38729 name: 39
# 2026-02-06 17:37:27 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:38729
# 2026-02-06 17:37:27 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:35772
# 2026-02-06 17:37:27 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:39421 name: 38
# 2026-02-06 17:37:27 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:39421
# 2026-02-06 17:37:27 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:35768
# 2026-02-06 17:37:27 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:34067 name: 41
# 2026-02-06 17:37:27 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:34067
# 2026-02-06 17:37:27 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:35786
# 2026-02-06 17:37:27 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:37459 name: 42
# 2026-02-06 17:37:27 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:37459
# 2026-02-06 17:37:27 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:35802
# 2026-02-06 17:37:27 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:42143 name: 46
# 2026-02-06 17:37:27 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:42143
# 2026-02-06 17:37:27 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:35804
# 2026-02-06 17:37:27 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:45995 name: 45
# 2026-02-06 17:37:27 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:45995
# 2026-02-06 17:37:27 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:35814
# 2026-02-06 17:37:27 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:41861 name: 43
# 2026-02-06 17:37:27 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:41861
# 2026-02-06 17:37:27 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:35820
# 2026-02-06 17:37:27 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:46863 name: 47
# 2026-02-06 17:37:27 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:46863
# 2026-02-06 17:37:27 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:35826
# 2026-02-06 17:37:27 - distributed.scheduler - INFO - Register worker addr: tcp://127.0.0.1:40461 name: 44
# 2026-02-06 17:37:27 - distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:40461
# 2026-02-06 17:37:27 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:35822
# 2026-02-06 17:37:27 - distributed.scheduler - INFO - Receive client connection: Client-6a1846e1-03ac-11f1-9486-0a580a221712
# 2026-02-06 17:37:27 - distributed.core - INFO - Starting established connection to tcp://127.0.0.1:35828
# 2026-02-06 17:37:27 - fmu2ml.analysis.nonlinear_characterization.analyzers.threshold_detector - INFO - Dask client initialized: http://127.0.0.1:37127/status
# 2026-02-06 17:37:27 - fmu2ml.analysis.nonlinear_characterization.analyzers.threshold_detector - INFO - Executing 42 threshold detection tasks...
# 2026-02-06 17:37:36 - fmu2ml.analysis.nonlinear_characterization.analyzers.threshold_detector - INFO - Detected thresholds for 42 pairs
# Relationships analyzed: 42
# Thresholds detected: 5
# Saturation detected: 1
#
# Pairs with Thresholds (5):
#      input                      output  n_breakpoints     linear_r2  \
# 12  Q_flow  V_flow_prim_GPM_datacenter              1  9.473642e-08
# 26   T_Air  V_flow_prim_GPM_datacenter              3  9.045311e-02
# 27   T_Air                         pue              2  8.956386e-05
# 40   T_ext  V_flow_prim_GPM_datacenter              2  5.884220e-03
# 41   T_ext                         pue              2  8.932019e-03
#
#     segmented_r2  r2_improvement  has_threshold  has_saturation  \
# 12      0.021973        0.021973           True           False
# 26      0.138417        0.047964           True           False
# 27      0.022615        0.022526           True           False
# 40      0.016137        0.010252           True            True
# 41      0.031470        0.022538           True           False
#
#     regime_changes
# 12            True
# 26            True
# 27            True
# 40            True
# 41            True
# 2026-02-06 17:37:43 - distributed.scheduler - INFO - Remove client Client-6a1846e1-03ac-11f1-9486-0a580a221712
# 2026-02-06 17:37:43 - distributed.core - INFO - Received 'close-stream' from tcp://127.0.0.1:35828; closing.
# 2026-02-06 17:37:43 - distributed.scheduler - INFO - Remove client Client-6a1846e1-03ac-11f1-9486-0a580a221712
# 2026-02-06 17:37:43 - distributed.scheduler - INFO - Close client connection: Client-6a1846e1-03ac-11f1-9486-0a580a221712

# %%
# Threshold Details
# Analyze threshold characteristics
if not threshold_pairs.empty:
    print("\nThreshold Characteristics:")
    print(f"  Mean breakpoints: {threshold_pairs['n_breakpoints'].mean():.1f}")
    print(f"  Most common: {threshold_pairs['n_breakpoints'].mode()[0] if not threshold_pairs.empty else 'N/A'} breakpoints")
    
    
    print(f"  Mean R-square improvement: {threshold_pairs['r2_improvement'].mean():.2f}")

# Saturation analysis
saturation_pairs = threshold_df[threshold_df['has_saturation']]
if not saturation_pairs.empty:
    print(f"\nSaturation Behavior ({len(saturation_pairs)} pairs):")
    print(saturation_pairs[['input', 'output', 'n_breakpoints']])
# Out:
# Threshold Characteristics:
#   Mean breakpoints: 2.0
#   Most common: 2 breakpoints
#   Mean R-square improvement: 0.03
#
# Saturation Behavior (1 pairs):
#     input                      output  n_breakpoints
# 40  T_ext  V_flow_prim_GPM_datacenter              2

# %%
#  Generate Segmented Fit Data
print("Generating segmented fit data for visualization...")
fit_data_dict = {}

for input_name in threshold_detector.input_vars:
    for output_name in KEY_OUTPUTS:
        if output_name in all_outputs:
            fit_data = threshold_detector.get_segmented_fit_data(
                prepared_data, input_name, output_name
            )
            if fit_data:
                fit_data_dict[(input_name, output_name)] = fit_data

print(f"Segmented fit data generated for {len(fit_data_dict)} pairs")
# Out:
# Generating segmented fit data for visualization...
# Segmented fit data generated for 9 pairs

# %%
# Threshold Visualizations
threshold_viz_dir = os.path.join(OUTPUT_DIR, 'visualizations', 'thresholds')
os.makedirs(threshold_viz_dir, exist_ok=True)

print("Creating threshold visualizations...")
create_threshold_plots(
    fit_data_dict,
    threshold_viz_dir,
    n_workers=N_WORKERS
)

create_threshold_summary_plot(threshold_df, threshold_viz_dir)

# Display example
threshold_plots = [f for f in os.listdir(threshold_viz_dir) if f.startswith('threshold_')]
if threshold_plots:
    Image(filename=os.path.join(threshold_viz_dir, threshold_plots[0]))
# Out:
# 2026-02-06 17:37:39 - fmu2ml.analysis.nonlinear_characterization.visualizers.threshold_visualizer - INFO - Creating threshold plots in parallel...
# Creating threshold visualizations...
# 2026-02-06 17:37:40 - fmu2ml.analysis.nonlinear_characterization.visualizers.threshold_visualizer - INFO - Created 9/9 threshold plots
# 2026-02-06 17:37:40 - fmu2ml.analysis.nonlinear_characterization.visualizers.threshold_visualizer - INFO - Creating threshold summary plot...

# %%
Image(filename=os.path.join(threshold_viz_dir, threshold_plots[1]))

# %% [markdown]
# ## 3. Operating Regime Classification

# %%
# Operating Regime Classification
print("Classifying operating regimes...")
regime_df, regime_full_results = threshold_detector.classify_regimes_all_pairs(prepared_data)

print(f"\nRelationships analyzed: {len(regime_df)}")
print(f"Mean number of regimes: {regime_df['n_regimes'].mean():.1f}")

# Regime distribution
print("\nRegime Distribution:")
print(regime_df['n_regimes'].value_counts().sort_index())

# Multi-regime pairs
multi_regime = regime_df[regime_df['n_regimes'] > 2]
print(f"\nPairs with 3+ regimes: {len(multi_regime)}")
if not multi_regime.empty:
    print(multi_regime.nlargest(10, 'n_regimes')[['input', 'output', 'n_regimes']])
# Out:
# 2026-01-29 20:40:07 - fmu2ml.analysis.nonlinear_characterization.analyzers.threshold_detector - INFO - Classifying operating regimes for all pairs...
# 2026-01-29 20:40:07 - fmu2ml.analysis.nonlinear_characterization.analyzers.threshold_detector - INFO - Executing 42 regime classification tasks...
# Classifying operating regimes...
# 2026-01-29 20:40:43 - fmu2ml.analysis.nonlinear_characterization.analyzers.threshold_detector - INFO - Classified regimes for 42 pairs
# Relationships analyzed: 42
# Mean number of regimes: 3.5
#
# Regime Distribution:
# n_regimes
# 2     4
# 3    11
# 4    27
# Name: count, dtype: int64
#
# Pairs with 3+ regimes: 38
#      input           output  n_regimes
# 0   Q_flow  V_flow_prim_GPM          4
# 2   Q_flow   W_flow_CDUP_kW          4
# 3   Q_flow       T_prim_s_C          4
# 4   Q_flow       T_prim_r_C          4
# 5   Q_flow        T_sec_s_C          4
# 6   Q_flow        T_sec_r_C          4
# 7   Q_flow    p_prim_s_psig          4
# 8   Q_flow    p_prim_r_psig          4
# 9   Q_flow     p_sec_s_psig          4
# 10  Q_flow     p_sec_r_psig          4

# %%
#  Regime Analysis Details
for input_var in ['Q_flow', 'T_Air', 'T_ext']:
    input_regimes = regime_df[regime_df['input'] == input_var]
    
    print(f"\n{input_var} Regime Analysis:")
    print(f"  Mean regimes: {input_regimes['n_regimes'].mean():.1f}")
    print(f"  Max regimes: {input_regimes['n_regimes'].max():.0f}")
    print(f"  Multi-regime pairs: {(input_regimes['n_regimes'] > 2).sum()}")
# Out:
# Q_flow Regime Analysis:
#   Mean regimes: 3.6
#   Max regimes: 4
#   Multi-regime pairs: 12
#
# T_Air Regime Analysis:
#   Mean regimes: 3.9
#   Max regimes: 4
#   Multi-regime pairs: 14
#
# T_ext Regime Analysis:
#   Mean regimes: 3.1
#   Max regimes: 4
#   Multi-regime pairs: 12

# %%
#  Regime Visualizations
regime_viz_dir = os.path.join(OUTPUT_DIR, 'visualizations', 'regimes')
os.makedirs(regime_viz_dir, exist_ok=True)

print("Creating regime visualizations...")
create_regime_scatter_plots(
    regime_full_results,
    regime_viz_dir,
    n_workers=N_WORKERS
)

# create_regime_summary_plot(regime_df, regime_viz_dir)

# Display example
regime_plots = [f for f in os.listdir(regime_viz_dir) if f.startswith('regime_')]
if regime_plots:
    Image(filename=os.path.join(regime_viz_dir, regime_plots[0]))
# Out:
# 2026-01-29 20:49:05 - fmu2ml.analysis.nonlinear_characterization.visualizers.regime_visualizer - INFO - Creating regime scatter plots in parallel...
# Creating regime visualizations...
# 2026-01-29 20:49:09 - fmu2ml.analysis.nonlinear_characterization.visualizers.regime_visualizer - INFO - Created 42/42 regime plots

# %%
#  Integrated Analysis - Nonlinearity Summary
print("="*60)
print("NONLINEARITY ANALYSIS SUMMARY")
print("="*60)

print(f"\nTotal Input-Output Pairs: {len(comparison_df)}")

# Overall nonlinearity
mean_improvement = comparison_df['r2_improvement_pct'].mean()
print(f"\nAverage R² Improvement: {mean_improvement:.2f}%")

# Categorize by improvement
weak = (comparison_df['r2_improvement_pct'] < 2).sum()
moderate = ((comparison_df['r2_improvement_pct'] >= 2) & 
            (comparison_df['r2_improvement_pct'] < 5)).sum()
strong = (comparison_df['r2_improvement_pct'] >= 5).sum()

print(f"\nNonlinearity Strength:")
print(f"  Weak (<2%): {weak} ({weak/len(comparison_df)*100:.1f}%)")
print(f"  Moderate (2-5%): {moderate} ({moderate/len(comparison_df)*100:.1f}%)")
print(f"  Strong (>5%): {strong} ({strong/len(comparison_df)*100:.1f}%)")

# Best polynomial degree distribution
print(f"\nOptimal Polynomial Degrees:")
for degree in sorted(comparison_df['best_degree'].unique()):
    count = (comparison_df['best_degree'] == degree).sum()
    print(f"  Degree {degree}: {count} ({count/len(comparison_df)*100:.1f}%)")
# Out:
# ============================================================
# NONLINEARITY ANALYSIS SUMMARY
# ============================================================
#
# Total Input-Output Pairs: 42
#
# Average R² Improvement: 738.45%
#
# Nonlinearity Strength:
#   Weak (<2%): 14 (33.3%)
#   Moderate (2-5%): 0 (0.0%)
#   Strong (>5%): 28 (66.7%)
#
# Optimal Polynomial Degrees:
#   Degree 1: 14 (33.3%)
#   Degree 3: 1 (2.4%)
#   Degree 4: 3 (7.1%)
#   Degree 5: 24 (57.1%)

# %%
#  Integrated Analysis - Threshold Summary
print("="*60)
print("THRESHOLD & SATURATION SUMMARY")
print("="*60)

has_threshold = threshold_df['has_threshold'].sum()
has_saturation = threshold_df['has_saturation'].sum()

print(f"\nThreshold Detection:")
print(f"  With thresholds: {has_threshold} ({has_threshold/len(threshold_df)*100:.1f}%)")
print(f"  With saturation: {has_saturation} ({has_saturation/len(threshold_df)*100:.1f}%)")

if has_threshold > 0:
    threshold_subset = threshold_df[threshold_df['has_threshold']]
    print(f"\nThreshold Characteristics:")
    print(f"  Avg breakpoints: {threshold_subset['n_breakpoints'].mean():.1f}")
    print(f"  Most common: {threshold_subset['n_breakpoints'].mode()[0]} breakpoints")
# Out:
# ============================================================
# THRESHOLD & SATURATION SUMMARY
# ============================================================
#
# Threshold Detection:
#   With thresholds: 28 (66.7%)
#   With saturation: 4 (9.5%)
#
# Threshold Characteristics:
#   Avg breakpoints: 2.8
#   Most common: 3 breakpoints

# %%
#  Integrated Analysis - Regime Summary
print("="*60)
print("OPERATING REGIME SUMMARY")
print("="*60)

print(f"\nRegime Statistics:")
print(f"  Mean regimes per pair: {regime_df['n_regimes'].mean():.1f}")
print(f"  Median regimes: {regime_df['n_regimes'].median():.0f}")
print(f"  Max regimes: {regime_df['n_regimes'].max():.0f}")

print(f"\nComplex Behavior:")
print(f"  Pairs with 2 regimes: {(regime_df['n_regimes'] == 2).sum()}")
print(f"  Pairs with 3+ regimes: {(regime_df['n_regimes'] > 2).sum()}")
# Out:
# ============================================================
# OPERATING REGIME SUMMARY
# ============================================================
#
# Regime Statistics:
#   Mean regimes per pair: 3.5
#   Median regimes: 4
#   Max regimes: 4
#
# Complex Behavior:
#   Pairs with 2 regimes: 4
#   Pairs with 3+ regimes: 38

# %%
#  Neural Network Architecture Recommendations
print("="*60)
print("NEURAL NETWORK ARCHITECTURE RECOMMENDATIONS")
print("="*60)

print("\n1. Activation Functions:")
if mean_improvement > 5:
    print("   ✓ STRONG RECOMMENDATION: Use non-linear activations (ReLU, tanh, etc.)")
    print(f"     Justification: {mean_improvement:.1f}% avg improvement with polynomial fits")
elif mean_improvement > 2:
    print("   ⚠ MODERATE RECOMMENDATION: Non-linear activations beneficial")
    print(f"     Justification: {mean_improvement:.1f}% avg improvement")
else:
    print("   ○ WEAK SIGNAL: Linear models may suffice for many relationships")
    print(f"     Note: Only {mean_improvement:.1f}% avg improvement")

print("\n2. Network Depth:")
max_degree = comparison_df['best_degree'].max()
mean_degree = comparison_df['best_degree'].mean()

if mean_degree > 3:
    print(f"   ✓ DEEP NETWORK: 3+ hidden layers recommended")
    print(f"     Justification: Mean optimal degree = {mean_degree:.1f}")
elif mean_degree > 2:
    print(f"   ⚠ MODERATE DEPTH: 2-3 hidden layers")
else:
    print(f"   ○ SHALLOW NETWORK: 1-2 layers may be sufficient")

print("\n3. Special Architectures:")
if has_threshold > len(threshold_df) * 0.2:
    print("   ✓ MIXTURE OF EXPERTS: Consider due to threshold behavior")
    print(f"     {has_threshold} relationships show threshold effects")

if (regime_df['n_regimes'] > 2).sum() > len(regime_df) * 0.2:
    print("   ✓ CONDITIONAL NETWORKS: Multiple operating regimes detected")
    print(f"     {(regime_df['n_regimes'] > 2).sum()} pairs have 3+ regimes")
# Out:
# ============================================================
# NEURAL NETWORK ARCHITECTURE RECOMMENDATIONS
# ============================================================
#
# 1. Activation Functions:
#    ✓ STRONG RECOMMENDATION: Use non-linear activations (ReLU, tanh, etc.)
#      Justification: 738.5% avg improvement with polynomial fits
#
# 2. Network Depth:
#    ✓ DEEP NETWORK: 3+ hidden layers recommended
#      Justification: Mean optimal degree = 3.5
#
# 3. Special Architectures:
#    ✓ MIXTURE OF EXPERTS: Consider due to threshold behavior
#      28 relationships show threshold effects
#    ✓ CONDITIONAL NETWORKS: Multiple operating regimes detected
#      38 pairs have 3+ regimes

# %%
#  Input-Specific Recommendations
print("="*60)
print("INPUT-SPECIFIC MODELING RECOMMENDATIONS")
print("="*60)

for input_var in ['Q_flow', 'T_Air', 'T_ext']:
    print(f"\n{input_var}:")
    
    # Nonlinearity
    input_comp = comparison_df[comparison_df['input'] == input_var]
    input_improvement = input_comp['r2_improvement_pct'].mean()
    print(f"  Avg nonlinearity: {input_improvement:.2f}%")
    
    # Thresholds
    input_thresh = threshold_df[threshold_df['input'] == input_var]
    thresh_pct = input_thresh['has_threshold'].sum() / len(input_thresh) * 100
    print(f"  Threshold effects: {thresh_pct:.1f}% of outputs")
    
    # Regimes
    input_regime = regime_df[regime_df['input'] == input_var]
    mean_regimes = input_regime['n_regimes'].mean()
    print(f"  Avg operating regimes: {mean_regimes:.1f}")
    
    # Recommendation
    if input_improvement > 5 or thresh_pct > 20:
        print(f"  → HIGH COMPLEXITY: Non-linear processing essential")
    elif input_improvement > 2 or thresh_pct > 10:
        print(f"  → MODERATE COMPLEXITY: Non-linear features beneficial")
    else:
        print(f"  → LOW COMPLEXITY: Linear processing may suffice")
# Out:
# ============================================================
# INPUT-SPECIFIC MODELING RECOMMENDATIONS
# ============================================================
#
# Q_flow:
#   Avg nonlinearity: 1868.68%
#   Threshold effects: 92.9% of outputs
#   Avg operating regimes: 3.6
#   → HIGH COMPLEXITY: Non-linear processing essential
#
# T_Air:
#   Avg nonlinearity: 280.03%
#   Threshold effects: 92.9% of outputs
#   Avg operating regimes: 3.9
#   → HIGH COMPLEXITY: Non-linear processing essential
#
# T_ext:
#   Avg nonlinearity: 66.64%
#   Threshold effects: 14.3% of outputs
#   Avg operating regimes: 3.1
#   → HIGH COMPLEXITY: Non-linear processing essential

# %%
#  Save All Results
print("Saving results...")

# Save dataframes
comparison_df.to_csv(os.path.join(OUTPUT_DIR, 'model_comparison.csv'), index=False)
polynomial_df.to_csv(os.path.join(OUTPUT_DIR, 'polynomial_fits.csv'), index=False)
threshold_df.to_csv(os.path.join(OUTPUT_DIR, 'threshold_detection.csv'), index=False)
regime_df.to_csv(os.path.join(OUTPUT_DIR, 'regime_classification.csv'), index=False)

print(f"\nAll results saved to: {OUTPUT_DIR}")
print("\nFiles created:")
print("  - sensitivity_data.parquet")
print("  - model_comparison.csv")
print("  - polynomial_fits.csv")
print("  - threshold_detection.csv")
print("  - regime_classification.csv")
print("  - visualizations/polynomial/")
print("  - visualizations/residuals/")
print("  - visualizations/thresholds/")
print("  - visualizations/regimes/")
print("  - visualizations/nonlinearity_strength/")
# Out:
# Saving results...
#
# All results saved to: ../results/lassen/data_analysis/nonlinear_characterization
#
# Files created:
#   - sensitivity_data.parquet
#   - model_comparison.csv
#   - polynomial_fits.csv
#   - threshold_detection.csv
#   - regime_classification.csv
#   - visualizations/polynomial/
#   - visualizations/residuals/
#   - visualizations/thresholds/
#   - visualizations/regimes/
#   - visualizations/nonlinearity_strength/

# %%
#  Export Summary Report
summary_report = {
    'system_name': SYSTEM_NAME,
    'n_samples': N_SAMPLES,
    'n_relationships': len(comparison_df),
    'nonlinearity': {
        'mean_r2_improvement_pct': mean_improvement,
        'strongly_nonlinear_count': strong,
        'mean_optimal_degree': mean_degree,
        'max_optimal_degree': max_degree
    },
    'thresholds': {
        'total_with_thresholds': int(has_threshold),
        'total_with_saturation': int(has_saturation),
        'threshold_percentage': has_threshold/len(threshold_df)*100
    },
    'regimes': {
        'mean_regimes': regime_df['n_regimes'].mean(),
        'max_regimes': int(regime_df['n_regimes'].max()),
        'multi_regime_count': int((regime_df['n_regimes'] > 2).sum())
    }
}

# import json
# with open(os.path.join(OUTPUT_DIR, 'analysis_summary.json'), 'w') as f:
#     json.dump(summary_report, f, indent=2)

# print("\nSummary report saved to analysis_summary.json")

# %%
#  Cleanup
nonlinear_analyzer._close_dask_client()
threshold_detector._close_dask_client()

print("\nAnalysis complete! Dask clients closed.")
# Out:
# 2026-02-06 17:37:42 - fmu2ml.analysis.nonlinear_characterization.analyzers.nonlinear_analyzer - INFO - Closing Dask cluster...
# 2026-02-06 17:37:42 - fmu2ml.analysis.nonlinear_characterization.analyzers.nonlinear_analyzer - INFO - Dask client closed
# 2026-02-06 17:37:42 - fmu2ml.analysis.nonlinear_characterization.analyzers.threshold_detector - INFO - Closing Dask cluster...
# Analysis complete! Dask clients closed.
